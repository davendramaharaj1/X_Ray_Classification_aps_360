# %%
import sagemaker
import boto3
from sagemaker.amazon.amazon_estimator import get_image_uri 
from sagemaker.session import s3_input, Session
# import uuid

# %% [markdown]
# ## Create bucket & Validation Region for S3

# %%
bucket_name = 'aps360project' # <--- CHANGE THIS VARIABLE TO A UNIQUE NAME FOR YOUR BUCKET
my_region = boto3.session.Session().region_name # set the region of the instance
print(my_region)
# Out:
# us-east-2

# %% [markdown]
# ## Create Paths to S3 Buckets for storage of model data

# %%
# Prefix for files in bucket
prefix = 'chest_x_ray_classification'

# Dataset directory
dataset = 'Xray_Dataset'

# Model output folder name
output_dir_name = 'trial_13'

# S3 Path bucket to get the data for training (Train, Test, Validation)
dataset_dir = 's3://{}/{}/{}'.format(bucket_name, prefix, dataset)

# output path for SageMaker to dump all model artifacts and graphs etc
output_dir = 's3://{}/{}/{}'.format(bucket_name, prefix, output_dir_name)

# # checkpoints for spot training
# checkpoint_suffix = str(uuid.uuid4())[:8]
# checkpoint_s3_path = 's3://{}/{}/{}/checkpoint-{}'.format(bucket_name, prefix, output_dir_name, checkpoint_suffix)

# sanity check for output path for model data
print('Dataset directory <dataset_dir>: ', dataset_dir)
print('Model Output directory <output_dir>: ', output_dir)
# print('Checkpointing Path: <checkpoint_s3_path>: {}'.format(checkpoint_s3_path))
# Out:
# Dataset directory <dataset_dir>:  s3://aps360project/chest_x_ray_classification/Xray_Dataset
# Model Output directory <output_dir>:  s3://aps360project/chest_x_ray_classification/trial_13

# %% [markdown]
# ## Manage Spot Training

# %%
# use_spot_instances = True
# max_run=24*60*60
# max_wait = 24*60*60

# %%
# initialize hyperparamters
hyperparameters = {
    'epochs': 8,
    'batch-size': 64,
    'learning-rate': 0.0005 
}

# Training instance
training_instance = 'ml.g4dn.xlarge'

# Create the current role to use sagemaker 
role = sagemaker.get_execution_role()

# %%
from sagemaker.pytorch import PyTorch

# Create a Pytorch estimator to run the training script on AWS Sagemaker
estimator = PyTorch(
                entry_point='trial13xray.py',
                role=role,
                framework_version='1.8.0',
                py_version='py3',
                output_path=output_dir,
                train_instance_count=1,
                script_mode=True,
                train_instance_type=training_instance,
                hyperparameters= hyperparameters,
                base_job_name='trial-13-MobileNetV3-bs-64-lr-0005-epoch-7',
            )
# Out:
# train_instance_count has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# train_instance_type has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.

# %%
estimator.fit({'training': dataset_dir})
# Out:
# 2021-04-03 23:29:59 Starting - Starting the training job...
# 2021-04-03 23:30:21 Starting - Launching requested ML instancesProfilerReport-1617492598: InProgress
# ......
# 2021-04-03 23:31:22 Starting - Preparing the instances for training...
# 2021-04-03 23:32:00 Downloading - Downloading input data......
# 2021-04-03 23:32:57 Training - Downloading the training image...............
# 2021-04-03 23:35:23 Training - Training image download completed. Training in progress.bash: cannot set terminal process group (-1): Inappropriate ioctl for device
# bash: no job control in this shell
# 2021-04-03 23:35:14,572 sagemaker-training-toolkit INFO     Imported framework sagemaker_pytorch_container.training
# 2021-04-03 23:35:14,593 sagemaker_pytorch_container.training INFO     Block until all host DNS lookups succeed.
# 2021-04-03 23:35:14,598 sagemaker_pytorch_container.training INFO     Invoking user training script.
# 2021-04-03 23:35:14,963 sagemaker-training-toolkit INFO     Invoking user script
#
# Training Env:
#
# {
#     "additional_framework_parameters": {},
#     "channel_input_dirs": {
#         "training": "/opt/ml/input/data/training"
#     },
#     "current_host": "algo-1",
#     "framework_module": "sagemaker_pytorch_container.training:main",
#     "hosts": [
#         "algo-1"
#     ],
#     "hyperparameters": {
#         "batch-size": 64,
#         "learning-rate": 0.0005,
#         "epochs": 8
#     },
#     "input_config_dir": "/opt/ml/input/config",
#     "input_data_config": {
#         "training": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         }
#     },
#     "input_dir": "/opt/ml/input",
#     "is_master": true,
#     "job_name": "trial-13-MobileNetV3-bs-64-lr-0005-epoc-2021-04-03-23-29-58-578",
#     "log_level": 20,
#     "master_hostname": "algo-1",
#     "model_dir": "/opt/ml/model",
#     "module_dir": "s3://aps360project/trial-13-MobileNetV3-bs-64-lr-0005-epoc-2021-04-03-23-29-58-578/source/sourcedir.tar.gz",
#     "module_name": "trial13xray",
#     "network_interface_name": "eth0",
#     "num_cpus": 4,
#     "num_gpus": 1,
#     "output_data_dir": "/opt/ml/output/data",
#     "output_dir": "/opt/ml/output",
#     "output_intermediate_dir": "/opt/ml/output/intermediate",
#     "resource_config": {
#         "current_host": "algo-1",
#         "hosts": [
#             "algo-1"
#         ],
#         "network_interface_name": "eth0"
#     },
#     "user_entry_point": "trial13xray.py"
# }
#
# Environment variables:
#
# SM_HOSTS=["algo-1"]
# SM_NETWORK_INTERFACE_NAME=eth0
# SM_HPS={"batch-size":64,"epochs":8,"learning-rate":0.0005}
# SM_USER_ENTRY_POINT=trial13xray.py
# SM_FRAMEWORK_PARAMS={}
# SM_RESOURCE_CONFIG={"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"}
# SM_INPUT_DATA_CONFIG={"training":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}}
# SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# SM_CHANNELS=["training"]
# SM_CURRENT_HOST=algo-1
# SM_MODULE_NAME=trial13xray
# SM_LOG_LEVEL=20
# SM_FRAMEWORK_MODULE=sagemaker_pytorch_container.training:main
# SM_INPUT_DIR=/opt/ml/input
# SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# SM_OUTPUT_DIR=/opt/ml/output
# SM_NUM_CPUS=4
# SM_NUM_GPUS=1
# SM_MODEL_DIR=/opt/ml/model
# SM_MODULE_DIR=s3://aps360project/trial-13-MobileNetV3-bs-64-lr-0005-epoc-2021-04-03-23-29-58-578/source/sourcedir.tar.gz
# SM_TRAINING_ENV={"additional_framework_parameters":{},"channel_input_dirs":{"training":"/opt/ml/input/data/training"},"current_host":"algo-1","framework_module":"sagemaker_pytorch_container.training:main","hosts":["algo-1"],"hyperparameters":{"batch-size":64,"epochs":8,"learning-rate":0.0005},"input_config_dir":"/opt/ml/input/config","input_data_config":{"training":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","is_master":true,"job_name":"trial-13-MobileNetV3-bs-64-lr-0005-epoc-2021-04-03-23-29-58-578","log_level":20,"master_hostname":"algo-1","model_dir":"/opt/ml/model","module_dir":"s3://aps360project/trial-13-MobileNetV3-bs-64-lr-0005-epoc-2021-04-03-23-29-58-578/source/sourcedir.tar.gz","module_name":"trial13xray","network_interface_name":"eth0","num_cpus":4,"num_gpus":1,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"},"user_entry_point":"trial13xray.py"}
# SM_USER_ARGS=["--batch-size","64","--epochs","8","--learning-rate","0.0005"]
# SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# SM_CHANNEL_TRAINING=/opt/ml/input/data/training
# SM_HP_BATCH-SIZE=64
# SM_HP_LEARNING-RATE=0.0005
# SM_HP_EPOCHS=8
# PYTHONPATH=/opt/ml/code:/opt/conda/bin:/opt/conda/lib/python36.zip:/opt/conda/lib/python3.6:/opt/conda/lib/python3.6/lib-dynload:/opt/conda/lib/python3.6/site-packages
#
# Invoking script with the following command:
#
# /opt/conda/bin/python3.6 trial13xray.py --batch-size 64 --epochs 8 --learning-rate 0.0005
#
#
# CUDA is available!  Training on GPU ...
# Training data: 3080
# Training Augmented data: 4616
# Validation data: 1020
# Testing data: 1024
# [2021-04-03 23:35:20.588 algo-1:26 INFO utils.py:27] RULE_JOB_STOP_SIGNAL_FILENAME: None
# [2021-04-03 23:35:20.661 algo-1:26 INFO profiler_config_parser.py:102] User has disabled profiler.
# [2021-04-03 23:35:20.661 algo-1:26 INFO json_config.py:91] Creating hook from json_config at /opt/ml/input/config/debughookconfig.json.
# [2021-04-03 23:35:20.661 algo-1:26 INFO hook.py:199] tensorboard_dir has not been set for the hook. SMDebug will not be exporting tensorboard summaries.
# [2021-04-03 23:35:20.662 algo-1:26 INFO hook.py:253] Saving to /opt/ml/output/tensors
# [2021-04-03 23:35:20.662 algo-1:26 INFO state_store.py:77] The checkpoint config file /opt/ml/input/config/checkpointconfig.json does not exist.
# [2021-04-03 23:35:25.658 algo-1:26 INFO hook.py:584] name:features.0.0.weight count_params:432
# [2021-04-03 23:35:25.671 algo-1:26 INFO hook.py:584] name:features.0.1.weight count_params:16
# [2021-04-03 23:35:25.671 algo-1:26 INFO hook.py:584] name:features.0.1.bias count_params:16
# [2021-04-03 23:35:25.671 algo-1:26 INFO hook.py:584] name:features.1.block.0.0.weight count_params:144
# [2021-04-03 23:35:25.671 algo-1:26 INFO hook.py:584] name:features.1.block.0.1.weight count_params:16
# [2021-04-03 23:35:25.671 algo-1:26 INFO hook.py:584] name:features.1.block.0.1.bias count_params:16
# [2021-04-03 23:35:25.672 algo-1:26 INFO hook.py:584] name:features.1.block.1.0.weight count_params:256
# [2021-04-03 23:35:25.672 algo-1:26 INFO hook.py:584] name:features.1.block.1.1.weight count_params:16
# [2021-04-03 23:35:25.672 algo-1:26 INFO hook.py:584] name:features.1.block.1.1.bias count_params:16
# [2021-04-03 23:35:25.672 algo-1:26 INFO hook.py:584] name:features.2.block.0.0.weight count_params:1024
# [2021-04-03 23:35:25.672 algo-1:26 INFO hook.py:584] name:features.2.block.0.1.weight count_params:64
# [2021-04-03 23:35:25.672 algo-1:26 INFO hook.py:584] name:features.2.block.0.1.bias count_params:64
# [2021-04-03 23:35:25.672 algo-1:26 INFO hook.py:584] name:features.2.block.1.0.weight count_params:576
# [2021-04-03 23:35:25.672 algo-1:26 INFO hook.py:584] name:features.2.block.1.1.weight count_params:64
# [2021-04-03 23:35:25.672 algo-1:26 INFO hook.py:584] name:features.2.block.1.1.bias count_params:64
# [2021-04-03 23:35:25.672 algo-1:26 INFO hook.py:584] name:features.2.block.2.0.weight count_params:1536
# [2021-04-03 23:35:25.673 algo-1:26 INFO hook.py:584] name:features.2.block.2.1.weight count_params:24
# [2021-04-03 23:35:25.673 algo-1:26 INFO hook.py:584] name:features.2.block.2.1.bias count_params:24
# [2021-04-03 23:35:25.673 algo-1:26 INFO hook.py:584] name:features.3.block.0.0.weight count_params:1728
# [2021-04-03 23:35:25.673 algo-1:26 INFO hook.py:584] name:features.3.block.0.1.weight count_params:72
# [2021-04-03 23:35:25.673 algo-1:26 INFO hook.py:584] name:features.3.block.0.1.bias count_params:72
# [2021-04-03 23:35:25.673 algo-1:26 INFO hook.py:584] name:features.3.block.1.0.weight count_params:648
# [2021-04-03 23:35:25.673 algo-1:26 INFO hook.py:584] name:features.3.block.1.1.weight count_params:72
# [2021-04-03 23:35:25.673 algo-1:26 INFO hook.py:584] name:features.3.block.1.1.bias count_params:72
# [2021-04-03 23:35:25.673 algo-1:26 INFO hook.py:584] name:features.3.block.2.0.weight count_params:1728
# [2021-04-03 23:35:25.673 algo-1:26 INFO hook.py:584] name:features.3.block.2.1.weight count_params:24
# [2021-04-03 23:35:25.673 algo-1:26 INFO hook.py:584] name:features.3.block.2.1.bias count_params:24
# [2021-04-03 23:35:25.673 algo-1:26 INFO hook.py:584] name:features.4.block.0.0.weight count_params:1728
# [2021-04-03 23:35:25.673 algo-1:26 INFO hook.py:584] name:features.4.block.0.1.weight count_params:72
# [2021-04-03 23:35:25.673 algo-1:26 INFO hook.py:584] name:features.4.block.0.1.bias count_params:72
# [2021-04-03 23:35:25.673 algo-1:26 INFO hook.py:584] name:features.4.block.1.0.weight count_params:1800
# [2021-04-03 23:35:25.673 algo-1:26 INFO hook.py:584] name:features.4.block.1.1.weight count_params:72
# [2021-04-03 23:35:25.673 algo-1:26 INFO hook.py:584] name:features.4.block.1.1.bias count_params:72
# [2021-04-03 23:35:25.673 algo-1:26 INFO hook.py:584] name:features.4.block.2.fc1.weight count_params:1728
# [2021-04-03 23:35:25.674 algo-1:26 INFO hook.py:584] name:features.4.block.2.fc1.bias count_params:24
# [2021-04-03 23:35:25.674 algo-1:26 INFO hook.py:584] name:features.4.block.2.fc2.weight count_params:1728
# [2021-04-03 23:35:25.674 algo-1:26 INFO hook.py:584] name:features.4.block.2.fc2.bias count_params:72
# [2021-04-03 23:35:25.674 algo-1:26 INFO hook.py:584] name:features.4.block.3.0.weight count_params:2880
# [2021-04-03 23:35:25.674 algo-1:26 INFO hook.py:584] name:features.4.block.3.1.weight count_params:40
# [2021-04-03 23:35:25.674 algo-1:26 INFO hook.py:584] name:features.4.block.3.1.bias count_params:40
# [2021-04-03 23:35:25.674 algo-1:26 INFO hook.py:584] name:features.5.block.0.0.weight count_params:4800
# [2021-04-03 23:35:25.674 algo-1:26 INFO hook.py:584] name:features.5.block.0.1.weight count_params:120
# [2021-04-03 23:35:25.674 algo-1:26 INFO hook.py:584] name:features.5.block.0.1.bias count_params:120
# [2021-04-03 23:35:25.674 algo-1:26 INFO hook.py:584] name:features.5.block.1.0.weight count_params:3000
# [2021-04-03 23:35:25.674 algo-1:26 INFO hook.py:584] name:features.5.block.1.1.weight count_params:120
# [2021-04-03 23:35:25.674 algo-1:26 INFO hook.py:584] name:features.5.block.1.1.bias count_params:120
# [2021-04-03 23:35:25.674 algo-1:26 INFO hook.py:584] name:features.5.block.2.fc1.weight count_params:3840
# [2021-04-03 23:35:25.674 algo-1:26 INFO hook.py:584] name:features.5.block.2.fc1.bias count_params:32
# [2021-04-03 23:35:25.674 algo-1:26 INFO hook.py:584] name:features.5.block.2.fc2.weight count_params:3840
# [2021-04-03 23:35:25.674 algo-1:26 INFO hook.py:584] name:features.5.block.2.fc2.bias count_params:120
# [2021-04-03 23:35:25.674 algo-1:26 INFO hook.py:584] name:features.5.block.3.0.weight count_params:4800
# [2021-04-03 23:35:25.674 algo-1:26 INFO hook.py:584] name:features.5.block.3.1.weight count_params:40
# [2021-04-03 23:35:25.674 algo-1:26 INFO hook.py:584] name:features.5.block.3.1.bias count_params:40
# [2021-04-03 23:35:25.675 algo-1:26 INFO hook.py:584] name:features.6.block.0.0.weight count_params:4800
# [2021-04-03 23:35:25.675 algo-1:26 INFO hook.py:584] name:features.6.block.0.1.weight count_params:120
# [2021-04-03 23:35:25.675 algo-1:26 INFO hook.py:584] name:features.6.block.0.1.bias count_params:120
# [2021-04-03 23:35:25.675 algo-1:26 INFO hook.py:584] name:features.6.block.1.0.weight count_params:3000
# [2021-04-03 23:35:25.675 algo-1:26 INFO hook.py:584] name:features.6.block.1.1.weight count_params:120
# [2021-04-03 23:35:25.675 algo-1:26 INFO hook.py:584] name:features.6.block.1.1.bias count_params:120
# [2021-04-03 23:35:25.675 algo-1:26 INFO hook.py:584] name:features.6.block.2.fc1.weight count_params:3840
# [2021-04-03 23:35:25.675 algo-1:26 INFO hook.py:584] name:features.6.block.2.fc1.bias count_params:32
# [2021-04-03 23:35:25.675 algo-1:26 INFO hook.py:584] name:features.6.block.2.fc2.weight count_params:3840
# [2021-04-03 23:35:25.675 algo-1:26 INFO hook.py:584] name:features.6.block.2.fc2.bias count_params:120
# [2021-04-03 23:35:25.675 algo-1:26 INFO hook.py:584] name:features.6.block.3.0.weight count_params:4800
# [2021-04-03 23:35:25.675 algo-1:26 INFO hook.py:584] name:features.6.block.3.1.weight count_params:40
# [2021-04-03 23:35:25.675 algo-1:26 INFO hook.py:584] name:features.6.block.3.1.bias count_params:40
# [2021-04-03 23:35:25.675 algo-1:26 INFO hook.py:584] name:features.7.block.0.0.weight count_params:9600
# [2021-04-03 23:35:25.675 algo-1:26 INFO hook.py:584] name:features.7.block.0.1.weight count_params:240
# [2021-04-03 23:35:25.675 algo-1:26 INFO hook.py:584] name:features.7.block.0.1.bias count_params:240
# [2021-04-03 23:35:25.675 algo-1:26 INFO hook.py:584] name:features.7.block.1.0.weight count_params:2160
# [2021-04-03 23:35:25.675 algo-1:26 INFO hook.py:584] name:features.7.block.1.1.weight count_params:240
# [2021-04-03 23:35:25.676 algo-1:26 INFO hook.py:584] name:features.7.block.1.1.bias count_params:240
# [2021-04-03 23:35:25.676 algo-1:26 INFO hook.py:584] name:features.7.block.2.0.weight count_params:19200
# [2021-04-03 23:35:25.676 algo-1:26 INFO hook.py:584] name:features.7.block.2.1.weight count_params:80
# [2021-04-03 23:35:25.676 algo-1:26 INFO hook.py:584] name:features.7.block.2.1.bias count_params:80
# [2021-04-03 23:35:25.676 algo-1:26 INFO hook.py:584] name:features.8.block.0.0.weight count_params:16000
# [2021-04-03 23:35:25.676 algo-1:26 INFO hook.py:584] name:features.8.block.0.1.weight count_params:200
# [2021-04-03 23:35:25.676 algo-1:26 INFO hook.py:584] name:features.8.block.0.1.bias count_params:200
# [2021-04-03 23:35:25.676 algo-1:26 INFO hook.py:584] name:features.8.block.1.0.weight count_params:1800
# [2021-04-03 23:35:25.676 algo-1:26 INFO hook.py:584] name:features.8.block.1.1.weight count_params:200
# [2021-04-03 23:35:25.676 algo-1:26 INFO hook.py:584] name:features.8.block.1.1.bias count_params:200
# [2021-04-03 23:35:25.676 algo-1:26 INFO hook.py:584] name:features.8.block.2.0.weight count_params:16000
# [2021-04-03 23:35:25.676 algo-1:26 INFO hook.py:584] name:features.8.block.2.1.weight count_params:80
# [2021-04-03 23:35:25.676 algo-1:26 INFO hook.py:584] name:features.8.block.2.1.bias count_params:80
# [2021-04-03 23:35:25.676 algo-1:26 INFO hook.py:584] name:features.9.block.0.0.weight count_params:14720
# [2021-04-03 23:35:25.676 algo-1:26 INFO hook.py:584] name:features.9.block.0.1.weight count_params:184
# [2021-04-03 23:35:25.676 algo-1:26 INFO hook.py:584] name:features.9.block.0.1.bias count_params:184
# [2021-04-03 23:35:25.676 algo-1:26 INFO hook.py:584] name:features.9.block.1.0.weight count_params:1656
# [2021-04-03 23:35:25.676 algo-1:26 INFO hook.py:584] name:features.9.block.1.1.weight count_params:184
# [2021-04-03 23:35:25.676 algo-1:26 INFO hook.py:584] name:features.9.block.1.1.bias count_params:184
# [2021-04-03 23:35:25.677 algo-1:26 INFO hook.py:584] name:features.9.block.2.0.weight count_params:14720
# [2021-04-03 23:35:25.677 algo-1:26 INFO hook.py:584] name:features.9.block.2.1.weight count_params:80
# [2021-04-03 23:35:25.677 algo-1:26 INFO hook.py:584] name:features.9.block.2.1.bias count_params:80
# [2021-04-03 23:35:25.677 algo-1:26 INFO hook.py:584] name:features.10.block.0.0.weight count_params:14720
# [2021-04-03 23:35:25.677 algo-1:26 INFO hook.py:584] name:features.10.block.0.1.weight count_params:184
# [2021-04-03 23:35:25.677 algo-1:26 INFO hook.py:584] name:features.10.block.0.1.bias count_params:184
# [2021-04-03 23:35:25.677 algo-1:26 INFO hook.py:584] name:features.10.block.1.0.weight count_params:1656
# [2021-04-03 23:35:25.677 algo-1:26 INFO hook.py:584] name:features.10.block.1.1.weight count_params:184
# [2021-04-03 23:35:25.677 algo-1:26 INFO hook.py:584] name:features.10.block.1.1.bias count_params:184
# [2021-04-03 23:35:25.677 algo-1:26 INFO hook.py:584] name:features.10.block.2.0.weight count_params:14720
# [2021-04-03 23:35:25.677 algo-1:26 INFO hook.py:584] name:features.10.block.2.1.weight count_params:80
# [2021-04-03 23:35:25.677 algo-1:26 INFO hook.py:584] name:features.10.block.2.1.bias count_params:80
# [2021-04-03 23:35:25.677 algo-1:26 INFO hook.py:584] name:features.11.block.0.0.weight count_params:38400
# [2021-04-03 23:35:25.677 algo-1:26 INFO hook.py:584] name:features.11.block.0.1.weight count_params:480
# [2021-04-03 23:35:25.677 algo-1:26 INFO hook.py:584] name:features.11.block.0.1.bias count_params:480
# [2021-04-03 23:35:25.677 algo-1:26 INFO hook.py:584] name:features.11.block.1.0.weight count_params:4320
# [2021-04-03 23:35:25.677 algo-1:26 INFO hook.py:584] name:features.11.block.1.1.weight count_params:480
# [2021-04-03 23:35:25.677 algo-1:26 INFO hook.py:584] name:features.11.block.1.1.bias count_params:480
# [2021-04-03 23:35:25.678 algo-1:26 INFO hook.py:584] name:features.11.block.2.fc1.weight count_params:57600
# [2021-04-03 23:35:25.678 algo-1:26 INFO hook.py:584] name:features.11.block.2.fc1.bias count_params:120
# [2021-04-03 23:35:25.678 algo-1:26 INFO hook.py:584] name:features.11.block.2.fc2.weight count_params:57600
# [2021-04-03 23:35:25.678 algo-1:26 INFO hook.py:584] name:features.11.block.2.fc2.bias count_params:480
# [2021-04-03 23:35:25.678 algo-1:26 INFO hook.py:584] name:features.11.block.3.0.weight count_params:53760
# [2021-04-03 23:35:25.678 algo-1:26 INFO hook.py:584] name:features.11.block.3.1.weight count_params:112
# [2021-04-03 23:35:25.678 algo-1:26 INFO hook.py:584] name:features.11.block.3.1.bias count_params:112
# [2021-04-03 23:35:25.678 algo-1:26 INFO hook.py:584] name:features.12.block.0.0.weight count_params:75264
# [2021-04-03 23:35:25.678 algo-1:26 INFO hook.py:584] name:features.12.block.0.1.weight count_params:672
# [2021-04-03 23:35:25.678 algo-1:26 INFO hook.py:584] name:features.12.block.0.1.bias count_params:672
# [2021-04-03 23:35:25.678 algo-1:26 INFO hook.py:584] name:features.12.block.1.0.weight count_params:6048
# [2021-04-03 23:35:25.678 algo-1:26 INFO hook.py:584] name:features.12.block.1.1.weight count_params:672
# [2021-04-03 23:35:25.678 algo-1:26 INFO hook.py:584] name:features.12.block.1.1.bias count_params:672
# [2021-04-03 23:35:25.678 algo-1:26 INFO hook.py:584] name:features.12.block.2.fc1.weight count_params:112896
# [2021-04-03 23:35:25.678 algo-1:26 INFO hook.py:584] name:features.12.block.2.fc1.bias count_params:168
# [2021-04-03 23:35:25.678 algo-1:26 INFO hook.py:584] name:features.12.block.2.fc2.weight count_params:112896
# [2021-04-03 23:35:25.678 algo-1:26 INFO hook.py:584] name:features.12.block.2.fc2.bias count_params:672
# [2021-04-03 23:35:25.679 algo-1:26 INFO hook.py:584] name:features.12.block.3.0.weight count_params:75264
# [2021-04-03 23:35:25.679 algo-1:26 INFO hook.py:584] name:features.12.block.3.1.weight count_params:112
# [2021-04-03 23:35:25.679 algo-1:26 INFO hook.py:584] name:features.12.block.3.1.bias count_params:112
# [2021-04-03 23:35:25.679 algo-1:26 INFO hook.py:584] name:features.13.block.0.0.weight count_params:75264
# [2021-04-03 23:35:25.679 algo-1:26 INFO hook.py:584] name:features.13.block.0.1.weight count_params:672
# [2021-04-03 23:35:25.679 algo-1:26 INFO hook.py:584] name:features.13.block.0.1.bias count_params:672
# [2021-04-03 23:35:25.679 algo-1:26 INFO hook.py:584] name:features.13.block.1.0.weight count_params:16800
# [2021-04-03 23:35:25.679 algo-1:26 INFO hook.py:584] name:features.13.block.1.1.weight count_params:672
# [2021-04-03 23:35:25.679 algo-1:26 INFO hook.py:584] name:features.13.block.1.1.bias count_params:672
# [2021-04-03 23:35:25.679 algo-1:26 INFO hook.py:584] name:features.13.block.2.fc1.weight count_params:112896
# [2021-04-03 23:35:25.682 algo-1:26 INFO hook.py:584] name:features.13.block.2.fc1.bias count_params:168
# [2021-04-03 23:35:25.683 algo-1:26 INFO hook.py:584] name:features.13.block.2.fc2.weight count_params:112896
# [2021-04-03 23:35:25.683 algo-1:26 INFO hook.py:584] name:features.13.block.2.fc2.bias count_params:672
# [2021-04-03 23:35:25.683 algo-1:26 INFO hook.py:584] name:features.13.block.3.0.weight count_params:107520
# [2021-04-03 23:35:25.683 algo-1:26 INFO hook.py:584] name:features.13.block.3.1.weight count_params:160
# [2021-04-03 23:35:25.683 algo-1:26 INFO hook.py:584] name:features.13.block.3.1.bias count_params:160
# [2021-04-03 23:35:25.683 algo-1:26 INFO hook.py:584] name:features.14.block.0.0.weight count_params:153600
# [2021-04-03 23:35:25.683 algo-1:26 INFO hook.py:584] name:features.14.block.0.1.weight count_params:960
# [2021-04-03 23:35:25.683 algo-1:26 INFO hook.py:584] name:features.14.block.0.1.bias count_params:960
# [2021-04-03 23:35:25.683 algo-1:26 INFO hook.py:584] name:features.14.block.1.0.weight count_params:24000
# [2021-04-03 23:35:25.683 algo-1:26 INFO hook.py:584] name:features.14.block.1.1.weight count_params:960
# [2021-04-03 23:35:25.683 algo-1:26 INFO hook.py:584] name:features.14.block.1.1.bias count_params:960
# [2021-04-03 23:35:25.683 algo-1:26 INFO hook.py:584] name:features.14.block.2.fc1.weight count_params:230400
# [2021-04-03 23:35:25.683 algo-1:26 INFO hook.py:584] name:features.14.block.2.fc1.bias count_params:240
# [2021-04-03 23:35:25.683 algo-1:26 INFO hook.py:584] name:features.14.block.2.fc2.weight count_params:230400
# [2021-04-03 23:35:25.683 algo-1:26 INFO hook.py:584] name:features.14.block.2.fc2.bias count_params:960
# [2021-04-03 23:35:25.684 algo-1:26 INFO hook.py:584] name:features.14.block.3.0.weight count_params:153600
# [2021-04-03 23:35:25.684 algo-1:26 INFO hook.py:584] name:features.14.block.3.1.weight count_params:160
# [2021-04-03 23:35:25.684 algo-1:26 INFO hook.py:584] name:features.14.block.3.1.bias count_params:160
# [2021-04-03 23:35:25.684 algo-1:26 INFO hook.py:584] name:features.15.block.0.0.weight count_params:153600
# [2021-04-03 23:35:25.684 algo-1:26 INFO hook.py:584] name:features.15.block.0.1.weight count_params:960
# [2021-04-03 23:35:25.684 algo-1:26 INFO hook.py:584] name:features.15.block.0.1.bias count_params:960
# [2021-04-03 23:35:25.684 algo-1:26 INFO hook.py:584] name:features.15.block.1.0.weight count_params:24000
# [2021-04-03 23:35:25.684 algo-1:26 INFO hook.py:584] name:features.15.block.1.1.weight count_params:960
# [2021-04-03 23:35:25.684 algo-1:26 INFO hook.py:584] name:features.15.block.1.1.bias count_params:960
# [2021-04-03 23:35:25.684 algo-1:26 INFO hook.py:584] name:features.15.block.2.fc1.weight count_params:230400
# [2021-04-03 23:35:25.684 algo-1:26 INFO hook.py:584] name:features.15.block.2.fc1.bias count_params:240
# [2021-04-03 23:35:25.684 algo-1:26 INFO hook.py:584] name:features.15.block.2.fc2.weight count_params:230400
# [2021-04-03 23:35:25.684 algo-1:26 INFO hook.py:584] name:features.15.block.2.fc2.bias count_params:960
# [2021-04-03 23:35:25.684 algo-1:26 INFO hook.py:584] name:features.15.block.3.0.weight count_params:153600
# [2021-04-03 23:35:25.684 algo-1:26 INFO hook.py:584] name:features.15.block.3.1.weight count_params:160
# [2021-04-03 23:35:25.684 algo-1:26 INFO hook.py:584] name:features.15.block.3.1.bias count_params:160
# [2021-04-03 23:35:25.684 algo-1:26 INFO hook.py:584] name:features.16.0.weight count_params:153600
# [2021-04-03 23:35:25.684 algo-1:26 INFO hook.py:584] name:features.16.1.weight count_params:960
# [2021-04-03 23:35:25.684 algo-1:26 INFO hook.py:584] name:features.16.1.bias count_params:960
# [2021-04-03 23:35:25.685 algo-1:26 INFO hook.py:584] name:classifier.0.weight count_params:1228800
# [2021-04-03 23:35:25.685 algo-1:26 INFO hook.py:584] name:classifier.0.bias count_params:1280
# [2021-04-03 23:35:25.685 algo-1:26 INFO hook.py:584] name:classifier.3.weight count_params:1280000
# [2021-04-03 23:35:25.685 algo-1:26 INFO hook.py:584] name:classifier.3.bias count_params:1000
# [2021-04-03 23:35:25.685 algo-1:26 INFO hook.py:584] name:fc.1.weight count_params:1280
# [2021-04-03 23:35:25.685 algo-1:26 INFO hook.py:584] name:fc.1.bias count_params:1280
# [2021-04-03 23:35:25.685 algo-1:26 INFO hook.py:584] name:fc.4.weight count_params:1280
# [2021-04-03 23:35:25.685 algo-1:26 INFO hook.py:584] name:fc.4.bias count_params:4
# [2021-04-03 23:35:25.685 algo-1:26 INFO hook.py:586] Total Trainable Params: 5486876
# [2021-04-03 23:35:25.685 algo-1:26 INFO hook.py:413] Monitoring the collections: losses
# [2021-04-03 23:35:25.689 algo-1:26 INFO hook.py:476] Hook is writing from the hook with pid: 26
#
# Epoch 0: Train acc: 0.16594454072790293 | Validation acc: 0.12058823529411765
# Epoch 0: Train acc: 0.16594454072790293 | Validation acc: 0.12058823529411765
# Epoch 1: Train acc: 0.6941074523396881 | Validation acc: 0.5941176470588235
# Epoch 1: Train acc: 0.6941074523396881 | Validation acc: 0.5941176470588235
# Epoch 2: Train acc: 0.8052426343154246 | Validation acc: 0.7009803921568627
# Epoch 2: Train acc: 0.8052426343154246 | Validation acc: 0.7009803921568627
# Epoch 3: Train acc: 0.8217071057192374 | Validation acc: 0.7362745098039216
# Epoch 3: Train acc: 0.8217071057192374 | Validation acc: 0.7362745098039216
