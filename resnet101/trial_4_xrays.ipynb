# %%
import sagemaker
import boto3
from sagemaker.amazon.amazon_estimator import get_image_uri 
from sagemaker.session import s3_input, Session

# %% [markdown]
# ## Create bucket & Validation Region for S3

# %%
bucket_name = 'aps360project' # <--- CHANGE THIS VARIABLE TO A UNIQUE NAME FOR YOUR BUCKET
my_region = boto3.session.Session().region_name # set the region of the instance
print(my_region)
# Out:
# us-east-2

# %% [markdown]
# ## Create Paths to S3 Buckets for storage of model data

# %%
# Prefix for files in bucket
prefix = 'chest_x_ray_classification'

# Dataset directory
dataset = 'Xray_Dataset'

# Model output folder name
output_dir_name = 'trial_4'

# S3 Path bucket to get the data for training (Train, Test, Validation)
dataset_dir = 's3://{}/{}/{}'.format(bucket_name, prefix, dataset)

# output path for SageMaker to dump all model artifacts and graphs etc
output_dir = 's3://{}/{}/{}'.format(bucket_name, prefix,output_dir_name)

# sanity check for output path for model data
print('Dataset directory <dataset_dir>: ', dataset_dir)
print('Model Output directory <output_dir>: ', output_dir)
# Out:
# Dataset directory <dataset_dir>:  s3://aps360project/chest_x_ray_classification/Xray_Dataset
# Model Output directory <output_dir>:  s3://aps360project/chest_x_ray_classification/trial_4

# %%
# initialize hyperparamters
hyperparameters = {
    'epochs': 4,
    'batch-size': 256,
    'learning-rate': 0.0001 
}

# Training instance
training_instance = 'ml.g4dn.xlarge'

# Create the current role to use sagemaker 
role = sagemaker.get_execution_role()

# %%
from sagemaker.pytorch import PyTorch

# Create a Pytorch estimator to run the training script on AWS Sagemaker
estimator = PyTorch(
                entry_point='trial4xray.py',
                role=role,
                framework_version='1.8.0',
                py_version='py3',
                output_path=output_dir,
                train_instance_count=1,
                script_mode=True,
                train_instance_type=training_instance,
                hyperparameters= hyperparameters,
            )
# Out:
# train_instance_count has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# train_instance_type has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.

# %%
estimator.fit({'training': dataset_dir})
# Out:
# 2021-04-01 04:12:15 Starting - Starting the training job...
# 2021-04-01 04:12:17 Starting - Launching requested ML instancesProfilerReport-1617250335: InProgress
# ......
# 2021-04-01 04:13:30 Starting - Preparing the instances for training...
# 2021-04-01 04:14:11 Downloading - Downloading input data......
# 2021-04-01 04:15:11 Training - Downloading the training image..............bash: cannot set terminal process group (-1): Inappropriate ioctl for device
# bash: no job control in this shell
# 2021-04-01 04:17:26,478 sagemaker-training-toolkit INFO     Imported framework sagemaker_pytorch_container.training
# 2021-04-01 04:17:26,501 sagemaker_pytorch_container.training INFO     Block until all host DNS lookups succeed.
# 2021-04-01 04:17:29,519 sagemaker_pytorch_container.training INFO     Invoking user training script.
# 2021-04-01 04:17:29,864 sagemaker-training-toolkit INFO     Invoking user script
#
# Training Env:
#
# {
#     "additional_framework_parameters": {},
#     "channel_input_dirs": {
#         "training": "/opt/ml/input/data/training"
#     },
#     "current_host": "algo-1",
#     "framework_module": "sagemaker_pytorch_container.training:main",
#     "hosts": [
#         "algo-1"
#     ],
#     "hyperparameters": {
#         "batch-size": 256,
#         "learning-rate": 0.0001,
#         "epochs": 4
#     },
#     "input_config_dir": "/opt/ml/input/config",
#     "input_data_config": {
#         "training": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         }
#     },
#     "input_dir": "/opt/ml/input",
#     "is_master": true,
#     "job_name": "pytorch-training-2021-04-01-04-12-15-713",
#     "log_level": 20,
#     "master_hostname": "algo-1",
#     "model_dir": "/opt/ml/model",
#     "module_dir": "s3://aps360project/pytorch-training-2021-04-01-04-12-15-713/source/sourcedir.tar.gz",
#     "module_name": "trial4xray",
#     "network_interface_name": "eth0",
#     "num_cpus": 4,
#     "num_gpus": 1,
#     "output_data_dir": "/opt/ml/output/data",
#     "output_dir": "/opt/ml/output",
#     "output_intermediate_dir": "/opt/ml/output/intermediate",
#     "resource_config": {
#         "current_host": "algo-1",
#         "hosts": [
#             "algo-1"
#         ],
#         "network_interface_name": "eth0"
#     },
#     "user_entry_point": "trial4xray.py"
# }
#
# Environment variables:
#
# SM_HOSTS=["algo-1"]
# SM_NETWORK_INTERFACE_NAME=eth0
# SM_HPS={"batch-size":256,"epochs":4,"learning-rate":0.0001}
# SM_USER_ENTRY_POINT=trial4xray.py
# SM_FRAMEWORK_PARAMS={}
# SM_RESOURCE_CONFIG={"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"}
# SM_INPUT_DATA_CONFIG={"training":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}}
# SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# SM_CHANNELS=["training"]
# SM_CURRENT_HOST=algo-1
# SM_MODULE_NAME=trial4xray
# SM_LOG_LEVEL=20
# SM_FRAMEWORK_MODULE=sagemaker_pytorch_container.training:main
# SM_INPUT_DIR=/opt/ml/input
# SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# SM_OUTPUT_DIR=/opt/ml/output
# SM_NUM_CPUS=4
# SM_NUM_GPUS=1
# SM_MODEL_DIR=/opt/ml/model
# SM_MODULE_DIR=s3://aps360project/pytorch-training-2021-04-01-04-12-15-713/source/sourcedir.tar.gz
# SM_TRAINING_ENV={"additional_framework_parameters":{},"channel_input_dirs":{"training":"/opt/ml/input/data/training"},"current_host":"algo-1","framework_module":"sagemaker_pytorch_container.training:main","hosts":["algo-1"],"hyperparameters":{"batch-size":256,"epochs":4,"learning-rate":0.0001},"input_config_dir":"/opt/ml/input/config","input_data_config":{"training":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","is_master":true,"job_name":"pytorch-training-2021-04-01-04-12-15-713","log_level":20,"master_hostname":"algo-1","model_dir":"/opt/ml/model","module_dir":"s3://aps360project/pytorch-training-2021-04-01-04-12-15-713/source/sourcedir.tar.gz","module_name":"trial4xray","network_interface_name":"eth0","num_cpus":4,"num_gpus":1,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"},"user_entry_point":"trial4xray.py"}
# SM_USER_ARGS=["--batch-size","256","--epochs","4","--learning-rate","0.0001"]
# SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# SM_CHANNEL_TRAINING=/opt/ml/input/data/training
# SM_HP_BATCH-SIZE=256
# SM_HP_LEARNING-RATE=0.0001
# SM_HP_EPOCHS=4
# PYTHONPATH=/opt/ml/code:/opt/conda/bin:/opt/conda/lib/python36.zip:/opt/conda/lib/python3.6:/opt/conda/lib/python3.6/lib-dynload:/opt/conda/lib/python3.6/site-packages
#
# Invoking script with the following command:
#
# /opt/conda/bin/python3.6 trial4xray.py --batch-size 256 --epochs 4 --learning-rate 0.0001
#
#
#
# 2021-04-01 04:17:31 Training - Training image download completed. Training in progress.CUDA is available!  Training on GPU ...
# Training data: 3080
# Training Augmented data: 4616
# Validation data: 1020
# Testing data: 1024
# [2021-04-01 04:17:39.632 algo-1:25 INFO utils.py:27] RULE_JOB_STOP_SIGNAL_FILENAME: None
# [2021-04-01 04:17:39.734 algo-1:25 INFO profiler_config_parser.py:102] User has disabled profiler.
# [2021-04-01 04:17:39.734 algo-1:25 INFO json_config.py:91] Creating hook from json_config at /opt/ml/input/config/debughookconfig.json.
# [2021-04-01 04:17:39.734 algo-1:25 INFO hook.py:199] tensorboard_dir has not been set for the hook. SMDebug will not be exporting tensorboard summaries.
# [2021-04-01 04:17:39.735 algo-1:25 INFO hook.py:253] Saving to /opt/ml/output/tensors
# [2021-04-01 04:17:39.735 algo-1:25 INFO state_store.py:77] The checkpoint config file /opt/ml/input/config/checkpointconfig.json does not exist.
# [2021-04-01 04:17:48.182 algo-1:25 INFO hook.py:584] name:fc.0.weight count_params:2097152
# [2021-04-01 04:17:48.182 algo-1:25 INFO hook.py:584] name:fc.0.bias count_params:1024
# [2021-04-01 04:17:48.182 algo-1:25 INFO hook.py:584] name:fc.1.weight count_params:1024
# [2021-04-01 04:17:48.182 algo-1:25 INFO hook.py:584] name:fc.1.bias count_params:1024
# [2021-04-01 04:17:48.182 algo-1:25 INFO hook.py:584] name:fc.3.weight count_params:524288
# [2021-04-01 04:17:48.183 algo-1:25 INFO hook.py:584] name:fc.3.bias count_params:512
# [2021-04-01 04:17:48.183 algo-1:25 INFO hook.py:584] name:fc.4.weight count_params:2048
# [2021-04-01 04:17:48.183 algo-1:25 INFO hook.py:584] name:fc.4.bias count_params:4
# [2021-04-01 04:17:48.183 algo-1:25 INFO hook.py:586] Total Trainable Params: 2627076
# [2021-04-01 04:17:48.183 algo-1:25 INFO hook.py:413] Monitoring the collections: losses
# [2021-04-01 04:17:48.184 algo-1:25 INFO hook.py:476] Hook is writing from the hook with pid: 25
#
# Epoch 0: Train acc: 0.7086221837088388 | Validation acc: 0.6166666666666667
# Epoch 0: Train acc: 0.7086221837088388 | Validation acc: 0.6166666666666667
# Epoch 1: Train acc: 0.8082755632582322 | Validation acc: 0.7009803921568627
# Epoch 1: Train acc: 0.8082755632582322 | Validation acc: 0.7009803921568627
