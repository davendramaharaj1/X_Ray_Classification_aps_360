# %%
import sagemaker
import boto3
from sagemaker.amazon.amazon_estimator import get_image_uri 
from sagemaker.session import s3_input, Session
# import uuid

# %% [markdown]
# ## Create bucket & Validation Region for S3

# %%
bucket_name = 'aps360' # <--- CHANGE THIS VARIABLE TO A UNIQUE NAME FOR YOUR BUCKET
my_region = boto3.session.Session().region_name # set the region of the instance
print(my_region)
# Out:
# us-east-2

# %% [markdown]
# ## Create Paths to S3 Buckets for storage of model data

# %%
# Prefix for files in bucket
prefix = 'xrayclassification'

# Dataset directory
dataset = 'Xray_Dataset'

# Model output folder name
output_dir_name = 'trial_9'

# S3 Path bucket to get the data for training (Train, Test, Validation)
dataset_dir = 's3://{}/{}/{}'.format(bucket_name, prefix, dataset)

# output path for SageMaker to dump all model artifacts and graphs etc
output_dir = 's3://{}/{}/{}'.format(bucket_name, prefix, output_dir_name)

# # checkpoints for spot training
# checkpoint_suffix = str(uuid.uuid4())[:8]
# checkpoint_s3_path = 's3://{}/{}/{}/checkpoint-{}'.format(bucket_name, prefix, output_dir_name, checkpoint_suffix)

# sanity check for output path for model data
print('Dataset directory <dataset_dir>: ', dataset_dir)
print('Model Output directory <output_dir>: ', output_dir)
# print('Checkpointing Path: <checkpoint_s3_path>: {}'.format(checkpoint_s3_path))
# Out:
# Dataset directory <dataset_dir>:  s3://aps360/xrayclassification/Xray_Dataset
# Model Output directory <output_dir>:  s3://aps360/xrayclassification/trial_9

# %% [markdown]
# ## Manage Spot Training

# %%
# use_spot_instances = True
# max_run=24*60*60
# max_wait = 24*60*60

# %%
# initialize hyperparamters
hyperparameters = {
    'epochs': 9,
    'batch-size': 128,
    'learning-rate': 0.0005 
}

# Training instance
training_instance = 'ml.g4dn.2xlarge'

# Create the current role to use sagemaker 
role = sagemaker.get_execution_role()

# %%
from sagemaker.pytorch import PyTorch

# Create a Pytorch estimator to run the training script on AWS Sagemaker
estimator = PyTorch(
                entry_point='trial9xray.py',
                role=role,
                framework_version='1.8.0',
                py_version='py3',
                output_path=output_dir,
                train_instance_count=1,
                script_mode=True,
                train_instance_type=training_instance,
                hyperparameters= hyperparameters,
                base_job_name='trial-9-pytorch'
            )
# Out:
# train_instance_count has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# train_instance_type has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.

# %%
estimator.fit({'training': dataset_dir})
# Out:
# 2021-04-03 08:47:45 Starting - Starting the training job...
# 2021-04-03 08:47:47 Starting - Launching requested ML instancesProfilerReport-1617439665: InProgress
# ......
# 2021-04-03 08:49:08 Starting - Preparing the instances for training.........
# 2021-04-03 08:50:43 Downloading - Downloading input data...
# 2021-04-03 08:51:04 Training - Downloading the training image...............
# 2021-04-03 08:53:43 Training - Training image download completed. Training in progress.bash: cannot set terminal process group (-1): Inappropriate ioctl for device
# bash: no job control in this shell
# 2021-04-03 08:53:36,729 sagemaker-training-toolkit INFO     Imported framework sagemaker_pytorch_container.training
# 2021-04-03 08:53:36,750 sagemaker_pytorch_container.training INFO     Block until all host DNS lookups succeed.
# 2021-04-03 08:53:36,757 sagemaker_pytorch_container.training INFO     Invoking user training script.
# 2021-04-03 08:53:37,090 sagemaker-training-toolkit INFO     Invoking user script
#
# Training Env:
#
# {
#     "additional_framework_parameters": {},
#     "channel_input_dirs": {
#         "training": "/opt/ml/input/data/training"
#     },
#     "current_host": "algo-1",
#     "framework_module": "sagemaker_pytorch_container.training:main",
#     "hosts": [
#         "algo-1"
#     ],
#     "hyperparameters": {
#         "batch-size": 128,
#         "learning-rate": 0.0005,
#         "epochs": 9
#     },
#     "input_config_dir": "/opt/ml/input/config",
#     "input_data_config": {
#         "training": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         }
#     },
#     "input_dir": "/opt/ml/input",
#     "is_master": true,
#     "job_name": "trial-9-pytorch-2021-04-03-08-47-45-242",
#     "log_level": 20,
#     "master_hostname": "algo-1",
#     "model_dir": "/opt/ml/model",
#     "module_dir": "s3://aps360/trial-9-pytorch-2021-04-03-08-47-45-242/source/sourcedir.tar.gz",
#     "module_name": "trial9xray",
#     "network_interface_name": "eth0",
#     "num_cpus": 8,
#     "num_gpus": 1,
#     "output_data_dir": "/opt/ml/output/data",
#     "output_dir": "/opt/ml/output",
#     "output_intermediate_dir": "/opt/ml/output/intermediate",
#     "resource_config": {
#         "current_host": "algo-1",
#         "hosts": [
#             "algo-1"
#         ],
#         "network_interface_name": "eth0"
#     },
#     "user_entry_point": "trial9xray.py"
# }
#
# Environment variables:
#
# SM_HOSTS=["algo-1"]
# SM_NETWORK_INTERFACE_NAME=eth0
# SM_HPS={"batch-size":128,"epochs":9,"learning-rate":0.0005}
# SM_USER_ENTRY_POINT=trial9xray.py
# SM_FRAMEWORK_PARAMS={}
# SM_RESOURCE_CONFIG={"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"}
# SM_INPUT_DATA_CONFIG={"training":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}}
# SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# SM_CHANNELS=["training"]
# SM_CURRENT_HOST=algo-1
# SM_MODULE_NAME=trial9xray
# SM_LOG_LEVEL=20
# SM_FRAMEWORK_MODULE=sagemaker_pytorch_container.training:main
# SM_INPUT_DIR=/opt/ml/input
# SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# SM_OUTPUT_DIR=/opt/ml/output
# SM_NUM_CPUS=8
# SM_NUM_GPUS=1
# SM_MODEL_DIR=/opt/ml/model
# SM_MODULE_DIR=s3://aps360/trial-9-pytorch-2021-04-03-08-47-45-242/source/sourcedir.tar.gz
# SM_TRAINING_ENV={"additional_framework_parameters":{},"channel_input_dirs":{"training":"/opt/ml/input/data/training"},"current_host":"algo-1","framework_module":"sagemaker_pytorch_container.training:main","hosts":["algo-1"],"hyperparameters":{"batch-size":128,"epochs":9,"learning-rate":0.0005},"input_config_dir":"/opt/ml/input/config","input_data_config":{"training":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","is_master":true,"job_name":"trial-9-pytorch-2021-04-03-08-47-45-242","log_level":20,"master_hostname":"algo-1","model_dir":"/opt/ml/model","module_dir":"s3://aps360/trial-9-pytorch-2021-04-03-08-47-45-242/source/sourcedir.tar.gz","module_name":"trial9xray","network_interface_name":"eth0","num_cpus":8,"num_gpus":1,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"},"user_entry_point":"trial9xray.py"}
# SM_USER_ARGS=["--batch-size","128","--epochs","9","--learning-rate","0.0005"]
# SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# SM_CHANNEL_TRAINING=/opt/ml/input/data/training
# SM_HP_BATCH-SIZE=128
# SM_HP_LEARNING-RATE=0.0005
# SM_HP_EPOCHS=9
# PYTHONPATH=/opt/ml/code:/opt/conda/bin:/opt/conda/lib/python36.zip:/opt/conda/lib/python3.6:/opt/conda/lib/python3.6/lib-dynload:/opt/conda/lib/python3.6/site-packages
#
# Invoking script with the following command:
#
# /opt/conda/bin/python3.6 trial9xray.py --batch-size 128 --epochs 9 --learning-rate 0.0005
#
#
# CUDA is available!  Training on GPU ...
# Training data: 3080
# Training Augmented data: 4616
# Validation data: 1020
# Testing data: 1024
# [2021-04-03 08:53:44.340 algo-1:25 INFO utils.py:27] RULE_JOB_STOP_SIGNAL_FILENAME: None
# [2021
# Downloading: "https://download.pytorch.org/models/inception_v3_google-1a9a5a14.pth" to /root/.cache/torch/hub/checkpoints/inception_v3_google-1a9a5a14.pth
# #015  0%|          | 0.00/104M [00:00<?, ?B/s]#015  1%|          | 920k/104M [00:00<00:11, 9.37MB/s]#015  7%|▋         | 7.34M/104M [00:00<00:08, 12.6MB/s]#015 14%|█▎        | 14.3M/104M [00:00<00:05, 16.8MB/s]#015 20%|██        | 21.3M/104M [00:00<00:03, 21.9MB/s]#015 27%|██▋       | 28.3M/104M [00:00<00:02, 27.7MB/s]#015 34%|███▍      | 35.3M/104M [00:00<00:02, 34.0MB/s]#015 41%|████      | 42.4M/104M [00:00<00:01, 40.6MB/s]#015 48%|████▊     | 49.4M/104M [00:00<00:01, 46.9MB/s]#015 54%|█████▍    | 56.4M/104M [00:00<00:00, 52.6MB/s]#015 61%|██████    | 63.2M/104M [00:01<00:00, 57.1MB/s]#015 68%|██████▊   | 70.4M/104M [00:01<00:00, 61.1MB/s]#015 75%|███████▍  | 77.6M/104M [00:01<00:00, 64.9MB/s]#015 81%|████████▏ | 84.6M/104M [00:01<00:00, 67.0MB/s]#015 88%|████████▊ | 91.6M/104M [00:01<00:00, 68.9MB/s]#015 95%|█████████▍| 98.6M/104M [00:01<00:00, 69.9MB/s]#015100%|██████████| 104M/104M [00:01<00:00, 68.8MB/s]
# --- Logging error ---
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.6/logging/__init__.py", line 994, in emit
#     msg = self.format(record)
#   File "/opt/conda/lib/python3.6/logging/__init__.py", line 840, in format
#     return fmt.format(record)
#   File "/opt/conda/lib/python3.6/logging/__init__.py", line 577, in format
#     record.message = record.getMessage()
#   File "/opt/conda/lib/python3.6/logging/__init__.py", line 338, in getMessage
#     msg = msg % self.args
# TypeError: not all arguments converted during string formatting
# Call stack:
#   File "trial9xray.py", line 389, in <module>
#     train(inceptionv3, args)
#   File "trial9xray.py", line 185, in train
#     train_loader, val_loader, test_loader = get_data_loader(args.data_dir, args.batch_size)
#   File "trial9xray.py", line 90, in get_data_loader
#     logger.info('Training data:', len(train_data))
# Message: 'Training data:'
# Arguments: (3080,)
# --- Logging error ---
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.6/logging/__init__.py", line 994, in emit
#     msg = self.format(record)
# 2021-04-03 14:07:17,460 sagemaker-training-toolkit INFO     Reporting training SUCCESS
#   File "/opt/conda/lib/python3.6/logging/__init__.py", line 840, in format
#     return fmt.format(record)
#   File "/opt/conda/lib/python3.6/logging/__init__.py", line 577, in format
#     record.message = record.getMessage()
#   File "/opt/conda/lib/python3.6/logging/__init__.py", line 338, in getMessage
#     msg = msg % self.args
# TypeError: not all arguments converted during string formatting
# Call stack:
#   File "trial9xray.py", line 389, in <module>
#     train(inceptionv3, args)
#   File "trial9xray.py", line 185, in train
#     train_loader, val_loader, test_loader = get_data_loader(args.data_dir, args.batch_size)
#   File "trial9xray.py", line 92, in get_data_loader
#     logger.info('Training Augmented data:', len(train_data_new))
# Message: 'Training Augmented data:'
# Arguments: (4616,)
# --- Logging error ---
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.6/logging/__init__.py", line 994, in emit
#     msg = self.format(record)
#   File "/opt/conda/lib/python3.6/logging/__init__.py", line 840, in format
#     return fmt.format(record)
#   File "/opt/conda/lib/python3.6/logging/__init__.py", line 577, in format
#     record.message = record.getMessage()
#   File "/opt/conda/lib/python3.6/logging/__init__.py", line 338, in getMessage
#     msg = msg % self.args
# TypeError: not all arguments converted during string formatting
# Call stack:
#   File "trial9xray.py", line 389, in <module>
#     train(inceptionv3, args)
#   File "trial9xray.py", line 185, in train
#     train_loader, val_loader, test_loader = get_data_loader(args.data_dir, args.batch_size)
#   File "trial9xray.py", line 94, in get_data_loader
#     logger.info('Validation data:',len(val_data))
# Message: 'Validation data:'
# Arguments: (1020,)
# --- Logging error ---
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.6/logging/__init__.py", line 994, in emit
#     msg = self.format(record)
#   File "/opt/conda/lib/python3.6/logging/__init__.py", line 840, in format
#     return fmt.format(record)
#   File "/opt/conda/lib/python3.6/logging/__init__.py", line 577, in format
#     record.message = record.getMessage()
#   File "/opt/conda/lib/python3.6/logging/__init__.py", line 338, in getMessage
#     msg = msg % self.args
# TypeError: not all arguments converted during string formatting
# Call stack:
#   File "trial9xray.py", line 389, in <module>
#     train(inceptionv3, args)
#   File "trial9xray.py", line 185, in train
#     train_loader, val_loader, test_loader = get_data_loader(args.data_dir, args.batch_size)
#   File "trial9xray.py", line 96, in get_data_loader
#     logger.info('Testing data:',len(test_data))
# Message: 'Testing data:'
# Arguments: (1024,)
# INFO:__main__:Epoch 0: Train acc: 0.6011698440207972 | Validation acc: 0.5411764705882353
# INFO:__main__:Epoch 1: Train acc: 0.70342287694974 | Validation acc: 0.6127450980392157
# INFO:__main__:Epoch 2: Train acc: 0.7305025996533796 | Validation acc: 0.6245098039215686
# INFO:__main__:Epoch 3: Train acc: 0.733318890814558 | Validation acc: 0.638235294117647
# INFO:__main__:Epoch 4: Train acc: 0.7346187175043327 | Validation acc: 0.6333333333333333
# INFO:__main__:Epoch 5: Train acc: 0.7571490467937608 | Validation acc: 0.6450980392156863
# INFO:__main__:Epoch 6: Train acc: 0.7584488734835355 | Validation acc: 0.657843137254902
# INFO:__main__:Epoch 7: Train acc: 0.7707972270363952 | Validation acc: 0.6607843137254902
# INFO:__main__:Epoch 8: Train acc: 0.7755632582322357 | Validation acc: 0.6872549019607843
# INFO:__main__:Training Finished! Plotting Graphs...
# INFO:__main__:Total time elapsed: 18811.64 seconds
# INFO:__main__:Final Training Accuracy: 0.8331889081455806
# INFO:__main__:Final Validation Accuracy: 0.734313725490196
# INFO:__main__:Graphs plotted...train() exited...
#
#
# 2021-04-03 14:07:38 Uploading - Uploading generated training model
# 2021-04-03 14:09:18 Completed - Training job completed
# ProfilerReport-1617439665: IssuesFound
# Training seconds: 19132
# Billable seconds: 19132
