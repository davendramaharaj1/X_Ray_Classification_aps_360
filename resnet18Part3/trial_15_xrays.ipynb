# %%
import sagemaker
import boto3
from sagemaker.amazon.amazon_estimator import get_image_uri 
from sagemaker.session import s3_input, Session
# import uuid

# %% [markdown]
# ## Create bucket & Validation Region for S3

# %%
bucket_name = 'aps360' # <--- CHANGE THIS VARIABLE TO A UNIQUE NAME FOR YOUR BUCKET
my_region = boto3.session.Session().region_name # set the region of the instance
print(my_region)
# Out:
# us-east-2

# %% [markdown]
# ## Create Paths to S3 Buckets for storage of model data

# %%
# Prefix for files in bucket
prefix = 'xrayclassification'

# Dataset directory
dataset = 'Xray_Dataset'

# Model output folder name
output_dir_name = 'trial_15'

# S3 Path bucket to get the data for training (Train, Test, Validation)
dataset_dir = 's3://{}/{}/{}'.format(bucket_name, prefix, dataset)

# output path for SageMaker to dump all model artifacts and graphs etc
output_dir = 's3://{}/{}/{}'.format(bucket_name, prefix, output_dir_name)

# # checkpoints for spot training
# checkpoint_suffix = str(uuid.uuid4())[:8]
# checkpoint_s3_path = 's3://{}/{}/{}/checkpoint-{}'.format(bucket_name, prefix, output_dir_name, checkpoint_suffix)

# sanity check for output path for model data
print('Dataset directory <dataset_dir>: ', dataset_dir)
print('Model Output directory <output_dir>: ', output_dir)
# print('Checkpointing Path: <checkpoint_s3_path>: {}'.format(checkpoint_s3_path))
# Out:
# Dataset directory <dataset_dir>:  s3://aps360/xrayclassification/Xray_Dataset
# Model Output directory <output_dir>:  s3://aps360/xrayclassification/trial_15

# %% [markdown]
# ## Manage Spot Training

# %%
# use_spot_instances = True
# max_run=24*60*60
# max_wait = 24*60*60

# %%
# initialize hyperparamters
hyperparameters = {
    'epochs': 7,
    'batch-size': 128,
    'learning-rate': 0.0001 
}

# Training instance
training_instance = 'ml.g4dn.xlarge'

# Create the current role to use sagemaker 
role = sagemaker.get_execution_role()

# %%
from sagemaker.pytorch import PyTorch

# Create a Pytorch estimator to run the training script on AWS Sagemaker
estimator = PyTorch(
                entry_point='trial15xray.py',
                role=role,
                framework_version='1.8.0',
                py_version='py3',
                output_path=output_dir,
                train_instance_count=1,
                script_mode=True,
                train_instance_type=training_instance,
                hyperparameters= hyperparameters,
                base_job_name='trial-15-resnet18-bs-128-lr-0001-epoch-7'
            )
# Out:
# train_instance_count has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# train_instance_type has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.

# %%
estimator.fit({'training': dataset_dir})
# Out:
# 2021-04-04 10:27:02 Starting - Starting the training job...
# 2021-04-04 10:27:26 Starting - Launching requested ML instancesProfilerReport-1617532022: InProgress
# ......
# 2021-04-04 10:28:26 Starting - Preparing the instances for training......
# 2021-04-04 10:29:26 Downloading - Downloading input data......
# 2021-04-04 10:30:26 Training - Downloading the training image............
# 2021-04-04 10:32:27 Training - Training image download completed. Training in progress..bash: cannot set terminal process group (-1): Inappropriate ioctl for device
# bash: no job control in this shell
# 2021-04-04 10:32:20,813 sagemaker-training-toolkit INFO     Imported framework sagemaker_pytorch_container.training
# 2021-04-04 10:32:20,834 sagemaker_pytorch_container.training INFO     Block until all host DNS lookups succeed.
# 2021-04-04 10:32:21,058 sagemaker_pytorch_container.training INFO     Invoking user training script.
# 2021-04-04 10:32:21,528 sagemaker-training-toolkit INFO     Invoking user script
#
# Training Env:
#
# {
#     "additional_framework_parameters": {},
#     "channel_input_dirs": {
#         "training": "/opt/ml/input/data/training"
#     },
#     "current_host": "algo-1",
#     "framework_module": "sagemaker_pytorch_container.training:main",
#     "hosts": [
#         "algo-1"
#     ],
#     "hyperparameters": {
#         "batch-size": 128,
#         "learning-rate": 0.0001,
#         "epochs": 7
#     },
#     "input_config_dir": "/opt/ml/input/config",
#     "input_data_config": {
#         "training": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         }
#     },
#     "input_dir": "/opt/ml/input",
#     "is_master": true,
#     "job_name": "trial-15-resnet18-bs-128-lr-0001-epoch--2021-04-04-10-27-02-682",
#     "log_level": 20,
#     "master_hostname": "algo-1",
#     "model_dir": "/opt/ml/model",
#     "module_dir": "s3://aps360/trial-15-resnet18-bs-128-lr-0001-epoch--2021-04-04-10-27-02-682/source/sourcedir.tar.gz",
#     "module_name": "trial15xray",
#     "network_interface_name": "eth0",
#     "num_cpus": 4,
#     "num_gpus": 1,
#     "output_data_dir": "/opt/ml/output/data",
#     "output_dir": "/opt/ml/output",
#     "output_intermediate_dir": "/opt/ml/output/intermediate",
#     "resource_config": {
#         "current_host": "algo-1",
#         "hosts": [
#             "algo-1"
#         ],
#         "network_interface_name": "eth0"
#     },
#     "user_entry_point": "trial15xray.py"
# }
#
# Environment variables:
#
# SM_HOSTS=["algo-1"]
# SM_NETWORK_INTERFACE_NAME=eth0
# SM_HPS={"batch-size":128,"epochs":7,"learning-rate":0.0001}
# SM_USER_ENTRY_POINT=trial15xray.py
# SM_FRAMEWORK_PARAMS={}
# SM_RESOURCE_CONFIG={"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"}
# SM_INPUT_DATA_CONFIG={"training":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}}
# SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# SM_CHANNELS=["training"]
# SM_CURRENT_HOST=algo-1
# SM_MODULE_NAME=trial15xray
# SM_LOG_LEVEL=20
# SM_FRAMEWORK_MODULE=sagemaker_pytorch_container.training:main
# SM_INPUT_DIR=/opt/ml/input
# SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# SM_OUTPUT_DIR=/opt/ml/output
# SM_NUM_CPUS=4
# SM_NUM_GPUS=1
# SM_MODEL_DIR=/opt/ml/model
# SM_MODULE_DIR=s3://aps360/trial-15-resnet18-bs-128-lr-0001-epoch--2021-04-04-10-27-02-682/source/sourcedir.tar.gz
# SM_TRAINING_ENV={"additional_framework_parameters":{},"channel_input_dirs":{"training":"/opt/ml/input/data/training"},"current_host":"algo-1","framework_module":"sagemaker_pytorch_container.training:main","hosts":["algo-1"],"hyperparameters":{"batch-size":128,"epochs":7,"learning-rate":0.0001},"input_config_dir":"/opt/ml/input/config","input_data_config":{"training":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","is_master":true,"job_name":"trial-15-resnet18-bs-128-lr-0001-epoch--2021-04-04-10-27-02-682","log_level":20,"master_hostname":"algo-1","model_dir":"/opt/ml/model","module_dir":"s3://aps360/trial-15-resnet18-bs-128-lr-0001-epoch--2021-04-04-10-27-02-682/source/sourcedir.tar.gz","module_name":"trial15xray","network_interface_name":"eth0","num_cpus":4,"num_gpus":1,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"},"user_entry_point":"trial15xray.py"}
# SM_USER_ARGS=["--batch-size","128","--epochs","7","--learning-rate","0.0001"]
# SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# SM_CHANNEL_TRAINING=/opt/ml/input/data/training
# SM_HP_BATCH-SIZE=128
# SM_HP_LEARNING-RATE=0.0001
# SM_HP_EPOCHS=7
# PYTHONPATH=/opt/ml/code:/opt/conda/bin:/opt/conda/lib/python36.zip:/opt/conda/lib/python3.6:/opt/conda/lib/python3.6/lib-dynload:/opt/conda/lib/python3.6/site-packages
#
# Invoking script with the following command:
#
# /opt/conda/bin/python3.6 trial15xray.py --batch-size 128 --epochs 7 --learning-rate 0.0001
#
#
# CUDA is available!  Training on GPU ...
# Training data: 3080
# Training Augmented data: 4616
# Validation data: 1020
# Testing data: 1024
# [2021-04-04 10:32:28.091 algo-1:26 INFO utils.py:27] RULE_JOB_STOP_SIGNAL_FILENAME: None
# [2021-04-04 10:32:28.250 algo-1:26 INFO profiler_config_parser.py:102] User has disabled profiler.
# [2021-04-04 10:32:28.250 algo-1:26 INFO json_config.py:91] Creating hook from json_config at /opt/ml/input/config/debughookconfig.json.
# [2021-04-04 10:32:28.250 algo-1:26 INFO hook.py:199] tensorboard_dir has not been set for the hook. SMDebug will not be exporting tensorboard summaries.
# [2021-04-04 10:32:28.251 algo-1:26 INFO hook.py:253] Saving to /opt/ml/output/tensors
# [2021-04-04 10:32:28.251 algo-1:26 INFO state_store.py:77] The checkpoint config file /opt/ml/input/config/checkpointconfig.json does not exist.
# [2021-04-04 10:32:37.466 algo-1:26 INFO hook.py:584] name:conv1.weight count_params:9408
# [2021-04-04 10:32:37.466 algo-1:26 INFO hook.py:584] name:bn1.weight count_params:64
# [2021-04-04 10:32:37.467 algo-1:26 INFO hook.py:584] name:bn1.bias count_params:64
# [2021-04-04 10:32:37.467 algo-1:26 INFO hook.py:584] name:layer1.0.conv1.weight count_params:36864
# [2021-04-04 10:32:37.467 algo-1:26 INFO hook.py:584] name:layer1.0.bn1.weight count_params:64
# [2021-04-04 10:32:37.467 algo-1:26 INFO hook.py:584] name:layer1.0.bn1.bias count_params:64
# [2021-04-04 10:32:37.467 algo-1:26 INFO hook.py:584] name:layer1.0.conv2.weight count_params:36864
# [2021-04-04 10:32:37.467 algo-1:26 INFO hook.py:584] name:layer1.0.bn2.weight count_params:64
# [2021-04-04 10:32:37.467 algo-1:26 INFO hook.py:584] name:layer1.0.bn2.bias count_params:64
# [2021-04-04 10:32:37.467 algo-1:26 INFO hook.py:584] name:layer1.1.conv1.weight count_params:36864
# [2021-04-04 10:32:37.467 algo-1:26 INFO hook.py:584] name:layer1.1.bn1.weight count_params:64
# [2021-04-04 10:32:37.467 algo-1:26 INFO hook.py:584] name:layer1.1.bn1.bias count_params:64
# [2021-04-04 10:32:37.467 algo-1:26 INFO hook.py:584] name:layer1.1.conv2.weight count_params:36864
# [2021-04-04 10:32:37.467 algo-1:26 INFO hook.py:584] name:layer1.1.bn2.weight count_params:64
# [2021-04-04 10:32:37.467 algo-1:26 INFO hook.py:584] name:layer1.1.bn2.bias count_params:64
# [2021-04-04 10:32:37.467 algo-1:26 INFO hook.py:584] name:layer2.0.conv1.weight count_params:73728
# [2021-04-04 10:32:37.467 algo-1:26 INFO hook.py:584] name:layer2.0.bn1.weight count_params:128
# [2021-04-04 10:32:37.467 algo-1:26 INFO hook.py:584] name:layer2.0.bn1.bias count_params:128
# [2021-04-04 10:32:37.467 algo-1:26 INFO hook.py:584] name:layer2.0.conv2.weight count_params:147456
# [2021-04-04 10:32:37.467 algo-1:26 INFO hook.py:584] name:layer2.0.bn2.weight count_params:128
# [2021-04-04 10:32:37.467 algo-1:26 INFO hook.py:584] name:layer2.0.bn2.bias count_params:128
# [2021-04-04 10:32:37.468 algo-1:26 INFO hook.py:584] name:layer2.0.downsample.0.weight count_params:8192
# [2021-04-04 10:32:37.468 algo-1:26 INFO hook.py:584] name:layer2.0.downsample.1.weight count_params:128
# [2021-04-04 10:32:37.468 algo-1:26 INFO hook.py:584] name:layer2.0.downsample.1.bias count_params:128
# [2021-04-04 10:32:37.468 algo-1:26 INFO hook.py:584] name:layer2.1.conv1.weight count_params:147456
# [2021-04-04 10:32:37.468 algo-1:26 INFO hook.py:584] name:layer2.1.bn1.weight count_params:128
# [2021-04-04 10:32:37.468 algo-1:26 INFO hook.py:584] name:layer2.1.bn1.bias count_params:128
# [2021-04-04 10:32:37.468 algo-1:26 INFO hook.py:584] name:layer2.1.conv2.weight count_params:147456
# [2021-04-04 10:32:37.468 algo-1:26 INFO hook.py:584] name:layer2.1.bn2.weight count_params:128
# [2021-04-04 10:32:37.468 algo-1:26 INFO hook.py:584] name:layer2.1.bn2.bias count_params:128
# [2021-04-04 10:32:37.468 algo-1:26 INFO hook.py:584] name:layer3.0.conv1.weight count_params:294912
# [2021-04-04 10:32:37.468 algo-1:26 INFO hook.py:584] name:layer3.0.bn1.weight count_params:256
# [2021-04-04 10:32:37.468 algo-1:26 INFO hook.py:584] name:layer3.0.bn1.bias count_params:256
# [2021-04-04 10:32:37.468 algo-1:26 INFO hook.py:584] name:layer3.0.conv2.weight count_params:589824
# [2021-04-04 10:32:37.468 algo-1:26 INFO hook.py:584] name:layer3.0.bn2.weight count_params:256
# [2021-04-04 10:32:37.468 algo-1:26 INFO hook.py:584] name:layer3.0.bn2.bias count_params:256
# [2021-04-04 10:32:37.468 algo-1:26 INFO hook.py:584] name:layer3.0.downsample.0.weight count_params:32768
# [2021-04-04 10:32:37.468 algo-1:26 INFO hook.py:584] name:layer3.0.downsample.1.weight count_params:256
# [2021-04-04 10:32:37.469 algo-1:26 INFO hook.py:584] name:layer3.0.downsample.1.bias count_params:256
# [2021-04-04 10:32:37.469 algo-1:26 INFO hook.py:584] name:layer3.1.conv1.weight count_params:589824
# [2021-04-04 10:32:37.469 algo-1:26 INFO hook.py:584] name:layer3.1.bn1.weight count_params:256
# [2021-04-04 10:32:37.469 algo-1:26 INFO hook.py:584] name:layer3.1.bn1.bias count_params:256
# [2021-04-04 10:32:37.469 algo-1:26 INFO hook.py:584] name:layer3.1.conv2.weight count_params:589824
# [2021-04-04 10:32:37.469 algo-1:26 INFO hook.py:584] name:layer3.1.bn2.weight count_params:256
# [2021-04-04 10:32:37.469 algo-1:26 INFO hook.py:584] name:layer3.1.bn2.bias count_params:256
# [2021-04-04 10:32:37.469 algo-1:26 INFO hook.py:584] name:layer4.0.conv1.weight count_params:1179648
# [2021-04-04 10:32:37.469 algo-1:26 INFO hook.py:584] name:layer4.0.bn1.weight count_params:512
# [2021-04-04 10:32:37.469 algo-1:26 INFO hook.py:584] name:layer4.0.bn1.bias count_params:512
# [2021-04-04 10:32:37.469 algo-1:26 INFO hook.py:584] name:layer4.0.conv2.weight count_params:2359296
# [2021-04-04 10:32:37.469 algo-1:26 INFO hook.py:584] name:layer4.0.bn2.weight count_params:512
# [2021-04-04 10:32:37.469 algo-1:26 INFO hook.py:584] name:layer4.0.bn2.bias count_params:512
# [2021-04-04 10:32:37.469 algo-1:26 INFO hook.py:584] name:layer4.0.downsample.0.weight count_params:131072
# [2021-04-04 10:32:37.469 algo-1:26 INFO hook.py:584] name:layer4.0.downsample.1.weight count_params:512
# [2021-04-04 10:32:37.469 algo-1:26 INFO hook.py:584] name:layer4.0.downsample.1.bias count_params:512
# [2021-04-04 10:32:37.470 algo-1:26 INFO hook.py:584] name:layer4.1.conv1.weight count_params:2359296
# [2021-04-04 10:32:37.470 algo-1:26 INFO hook.py:584] name:layer4.1.bn1.weight count_params:512
# [2021-04-04 10:32:37.470 algo-1:26 INFO hook.py:584] name:layer4.1.bn1.bias count_params:512
# [2021-04-04 10:32:37.470 algo-1:26 INFO hook.py:584] name:layer4.1.conv2.weight count_params:2359296
# [2021-04-04 10:32:37.470 algo-1:26 INFO hook.py:584] name:layer4.1.bn2.weight count_params:512
# [2021-04-04 10:32:37.470 algo-1:26 INFO hook.py:584] name:layer4.1.bn2.bias count_params:512
# [2021-04-04 10:32:37.470 algo-1:26 INFO hook.py:584] name:fc.0.weight count_params:131072
# [2021-04-04 10:32:37.470 algo-1:26 INFO hook.py:584] name:fc.0.bias count_params:256
# [2021-04-04 10:32:37.470 algo-1:26 INFO hook.py:584] name:fc.1.weight count_params:256
# [2021-04-04 10:32:37.470 algo-1:26 INFO hook.py:584] name:fc.1.bias count_params:256
# [2021-04-04 10:32:37.470 algo-1:26 INFO hook.py:584] name:fc.3.weight count_params:32768
# [2021-04-04 10:32:37.470 algo-1:26 INFO hook.py:584] name:fc.3.bias count_params:128
# [2021-04-04 10:32:37.470 algo-1:26 INFO hook.py:584] name:fc.4.weight count_params:512
# [2021-04-04 10:32:37.470 algo-1:26 INFO hook.py:584] name:fc.4.bias count_params:4
# [2021-04-04 10:32:37.470 algo-1:26 INFO hook.py:586] Total Trainable Params: 11341764
# [2021-04-04 10:32:37.471 algo-1:26 INFO hook.py:413] Monitoring the collections: losses
# [2021-04-04 10:32:37.478 algo-1:26 INFO hook.py:476] Hook is writing from the hook with pid: 26
#
# Epoch 0: Train acc: 0.6503466204506065 | Validation acc: 0.5794117647058824
# Epoch 0: Train acc: 0.6503466204506065 | Validation acc: 0.5794117647058824
# Epoch 1: Train acc: 0.8011265164644714 | Validation acc: 0.7137254901960784
# Epoch 1: Train acc: 0.8011265164644714 | Validation acc: 0.7137254901960784
