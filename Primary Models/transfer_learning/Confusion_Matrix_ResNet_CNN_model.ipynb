# %%
import numpy as np
import time
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torchvision
from torch.utils.data.sampler import SubsetRandomSampler
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import torchvision.models
from PIL import Image
import pandas as pd

from sklearn.preprocessing import StandardScaler
from sklearn.metrics import confusion_matrix
from sklearn.externals import joblib
from sklearn.metrics import accuracy_score
from sklearn.metrics import plot_confusion_matrix
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/externals/joblib/__init__.py:15: FutureWarning: sklearn.externals.joblib is deprecated in 0.21 and will be removed in 0.23. Please import this functionality directly from joblib, which can be installed with: pip install joblib. If this warning is raised when loading pickled models, you may need to re-serialize those models with scikit-learn 0.21+.
#   warnings.warn(msg, category=FutureWarning)

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# ### Splitting Data

# %%
# # Directory to get data from
# dir = r'/content/gdrive/MyDrive/APS360/Project/SampleDataLarge/Pneumonia-Bacterial'
# # Directory to store training set
# train_dir = r'/content/gdrive/MyDrive/APS360/Project/sample_large/bacterial_train'
# # Directory to store testing set
# test_dir = r'/content/gdrive/MyDrive/APS360/Project/sample_large/bacterial_val'
# # Directory to store validation path
# valid_dir = r'/content/gdrive/MyDrive/APS360/Project/sample_large/bacterial_test'

# # Get the list of file paths in the directory of dataset
# files = [file for file in os.listdir(
#     dir) if os.path.isfile(os.path.join(dir, file))]
# # Input size of training set
# train_count = np.round(70 / 100 * len(files))
# # Input size of testing set
# test_count = np.round(15 / 100 * len(files))
# # Input size of validation set
# valid_count = np.round(15 / 100 * len(files))
# # Generate random numbers of file indices
# random_indices = list(random.sample(range(0, len(files)), len(files)))
# print("len(files)", len(files))

# # train_files indices
# print(random_indices)

# # training files
# train_file_index = random_indices[0:int(train_count) + 1]
# train_file_name = [files[i] for i in train_file_index]

# # testing files
# test_file_index = random_indices[int(
#     train_count) + 1:int(train_count + test_count) + 1]
# test_file_name = [files[i] for i in test_file_index]

# # validation files
# valid_file_index = random_indices[int(train_count + test_count) + 1:]
# valid_file_name = [files[i] for i in valid_file_index]

# # training files
# for train in train_file_name:
#     file = train
#     shutil.copyfile(os.path.join(dir, file), os.path.join(train_dir, file))
# # test_files
# for test in test_file_name:
#     file = test
#     shutil.copyfile(os.path.join(dir, file), os.path.join(test_dir, file))

# # valid_files
# for valid in valid_file_name:
#     file = valid
#     shutil.copyfile(os.path.join(dir, file), os.path.join(valid_dir, file))
# Out:
# len(files) 243
# [96, 76, 10, 46, 75, 26, 53, 238, 94, 206, 117, 81, 211, 176, 200, 186, 168, 216, 63, 142, 101, 103, 167, 99, 40, 27, 161, 25, 159, 172, 228, 213, 150, 37, 4, 52, 219, 199, 160, 74, 118, 184, 58, 11, 43, 174, 192, 189, 42, 116, 209, 197, 92, 31, 239, 44, 89, 1, 203, 180, 15, 88, 131, 132, 221, 242, 173, 32, 90, 98, 64, 19, 170, 77, 236, 62, 3, 124, 163, 109, 217, 154, 12, 232, 218, 104, 57, 187, 119, 133, 0, 229, 107, 128, 195, 204, 21, 22, 47, 240, 106, 16, 149, 157, 141, 115, 130, 45, 226, 34, 48, 177, 112, 143, 193, 227, 191, 233, 205, 135, 113, 35, 123, 136, 6, 224, 114, 198, 17, 8, 87, 29, 139, 155, 166, 153, 208, 196, 223, 84, 231, 138, 14, 148, 181, 151, 59, 127, 108, 65, 202, 18, 60, 2, 183, 51, 9, 28, 105, 85, 190, 49, 220, 121, 212, 169, 80, 23, 72, 54, 13, 68, 95, 61, 20, 179, 165, 129, 5, 70, 162, 102, 137, 56, 235, 97, 110, 156, 41, 125, 207, 111, 50, 214, 144, 67, 178, 120, 222, 134, 171, 71, 215, 140, 175, 185, 158, 126, 230, 24, 182, 237, 39, 201, 7, 241, 146, 33, 66, 69, 122, 83, 164, 86, 152, 55, 145, 91, 30, 100, 93, 36, 225, 82, 78, 79, 147, 188, 73, 210, 234, 38, 194]

# %%
# # Directory to get data from
# dir = r'/content/gdrive/MyDrive/APS360/Project/SampleDataLarge/Pneumonia-Viral'
# # Directory to store training set
# train_dir = r'/content/gdrive/MyDrive/APS360/Project/sample_large/viral_train'
# # Directory to store testing set
# test_dir = r'/content/gdrive/MyDrive/APS360/Project/sample_large/viral_val'
# # Directory to store validation path
# valid_dir = r'/content/gdrive/MyDrive/APS360/Project/sample_large/viral_test'

# # Get the list of file paths in the directory of dataset
# files = [file for file in os.listdir(
#     dir) if os.path.isfile(os.path.join(dir, file))]
# # Input size of training set
# train_count = np.round(70 / 100 * len(files))
# # Input size of testing set
# test_count = np.round(15 / 100 * len(files))
# # Input size of validation set
# valid_count = np.round(15 / 100 * len(files))
# # Generate random numbers of file indices
# random_indices = list(random.sample(range(0, len(files)), len(files)))
# print("len(files)", len(files))

# # train_files indices
# print(random_indices)

# # training files
# train_file_index = random_indices[0:int(train_count) + 1]
# train_file_name = [files[i] for i in train_file_index]

# # testing files
# test_file_index = random_indices[int(
#     train_count) + 1:int(train_count + test_count) + 1]
# test_file_name = [files[i] for i in test_file_index]

# # validation files
# valid_file_index = random_indices[int(train_count + test_count) + 1:]
# valid_file_name = [files[i] for i in valid_file_index]

# # training files
# for train in train_file_name:
#     file = train
#     shutil.copyfile(os.path.join(dir, file), os.path.join(train_dir, file))
# # test_files
# for test in test_file_name:
#     file = test
#     shutil.copyfile(os.path.join(dir, file), os.path.join(test_dir, file))

# # valid_files
# for valid in valid_file_name:
#     file = valid
#     shutil.copyfile(os.path.join(dir, file), os.path.join(valid_dir, file))
# Out:
# len(files) 250
# [42, 132, 138, 171, 170, 16, 175, 152, 20, 43, 213, 176, 126, 75, 28, 87, 244, 82, 74, 109, 6, 13, 84, 52, 195, 121, 66, 118, 24, 44, 49, 232, 163, 125, 209, 14, 113, 179, 154, 124, 181, 162, 218, 95, 133, 23, 80, 127, 139, 215, 115, 99, 180, 190, 226, 246, 10, 22, 204, 249, 92, 140, 210, 131, 187, 238, 70, 212, 120, 160, 21, 104, 145, 27, 8, 60, 107, 116, 17, 228, 184, 2, 166, 3, 4, 67, 167, 111, 108, 151, 169, 100, 182, 56, 142, 36, 240, 85, 158, 219, 174, 134, 178, 102, 137, 50, 155, 235, 53, 199, 206, 248, 71, 191, 19, 62, 90, 224, 98, 149, 18, 159, 48, 221, 1, 164, 207, 51, 129, 32, 157, 97, 222, 40, 231, 29, 135, 88, 96, 130, 25, 63, 237, 77, 69, 117, 91, 31, 208, 94, 173, 86, 46, 153, 185, 64, 177, 61, 101, 205, 217, 106, 26, 200, 89, 150, 223, 93, 147, 202, 68, 114, 79, 9, 197, 168, 58, 35, 188, 54, 59, 33, 112, 15, 196, 78, 30, 0, 216, 220, 34, 45, 156, 211, 57, 203, 198, 243, 229, 136, 39, 83, 245, 72, 242, 201, 193, 234, 105, 141, 41, 76, 236, 110, 119, 227, 183, 122, 239, 225, 12, 148, 214, 38, 144, 37, 241, 73, 47, 103, 81, 123, 165, 192, 146, 65, 11, 5, 143, 161, 7, 194, 128, 186, 55, 172, 233, 230, 247, 189]

# %%
# # Directory to get data from
# dir = r'/content/gdrive/MyDrive/APS360/Project/SampleDataLarge/Normal'
# # Directory to store training set
# train_dir = r'/content/gdrive/MyDrive/APS360/Project/sample_large/normal_train'
# # Directory to store testing set
# test_dir = r'/content/gdrive/MyDrive/APS360/Project/sample_large/normal_val'
# # Directory to store validation path
# valid_dir = r'/content/gdrive/MyDrive/APS360/Project/sample_large/normal_test'

# # Get the list of file paths in the directory of dataset
# files = [file for file in os.listdir(
#     dir) if os.path.isfile(os.path.join(dir, file))]
# # Input size of training set
# train_count = np.round(70 / 100 * len(files))
# # Input size of testing set
# test_count = np.round(15 / 100 * len(files))
# # Input size of validation set
# valid_count = np.round(15 / 100 * len(files))
# # Generate random numbers of file indices
# random_indices = list(random.sample(range(0, len(files)), len(files)))
# print("len(files)", len(files))

# # train_files indices
# print(random_indices)

# # training files
# train_file_index = random_indices[0:int(train_count) + 1]
# train_file_name = [files[i] for i in train_file_index]

# # testing files
# test_file_index = random_indices[int(
#     train_count) + 1:int(train_count + test_count) + 1]
# test_file_name = [files[i] for i in test_file_index]

# # validation files
# valid_file_index = random_indices[int(train_count + test_count) + 1:]
# valid_file_name = [files[i] for i in valid_file_index]

# # training files
# for train in train_file_name:
#     file = train
#     shutil.copyfile(os.path.join(dir, file), os.path.join(train_dir, file))
# # test_files
# for test in test_file_name:
#     file = test
#     shutil.copyfile(os.path.join(dir, file), os.path.join(test_dir, file))

# # valid_files
# for valid in valid_file_name:
#     file = valid
#     shutil.copyfile(os.path.join(dir, file), os.path.join(valid_dir, file))
# Out:
# len(files) 250
# [128, 152, 2, 12, 42, 140, 132, 20, 1, 144, 68, 60, 16, 193, 92, 181, 18, 214, 45, 73, 227, 163, 147, 63, 151, 15, 155, 180, 179, 217, 156, 82, 65, 98, 234, 113, 50, 88, 187, 27, 7, 171, 78, 85, 173, 10, 249, 200, 197, 149, 32, 51, 35, 202, 116, 17, 19, 136, 106, 192, 13, 108, 76, 235, 125, 239, 114, 138, 216, 24, 101, 33, 130, 178, 203, 224, 182, 122, 56, 90, 231, 243, 96, 11, 150, 31, 134, 199, 39, 49, 23, 89, 186, 145, 184, 204, 206, 75, 64, 242, 226, 124, 146, 97, 109, 0, 81, 232, 104, 111, 240, 28, 133, 119, 3, 209, 222, 158, 93, 176, 4, 102, 165, 205, 143, 169, 210, 148, 67, 170, 103, 168, 74, 34, 54, 208, 123, 99, 194, 212, 153, 107, 183, 154, 166, 225, 95, 37, 5, 38, 59, 8, 131, 118, 218, 69, 112, 228, 233, 221, 71, 139, 159, 9, 246, 175, 230, 247, 237, 48, 244, 58, 53, 29, 185, 117, 94, 57, 66, 91, 161, 160, 195, 21, 207, 44, 241, 36, 83, 25, 110, 172, 86, 41, 62, 72, 22, 84, 135, 248, 236, 238, 191, 196, 30, 115, 105, 52, 201, 198, 14, 79, 220, 190, 6, 229, 223, 157, 55, 87, 167, 162, 40, 46, 137, 245, 126, 219, 26, 189, 47, 127, 164, 215, 43, 121, 142, 70, 213, 77, 61, 141, 129, 80, 177, 100, 188, 120, 174, 211]

# %% [markdown]
# ### Load Data

# %%
def load_data(batch_size=64):
  # Compose allows us to have multiple transformations to occur
  # and resize all images to 224x224
  transform_it = transforms.Compose([transforms.Resize((224,224)), transforms.ToTensor()])

  # Save the paths of each of the different types of data that are located in my drive 
  train_path = '/content/gdrive/MyDrive/Primary Models/sample_large/train'
  val_path = '/content/gdrive/MyDrive/Primary Models/sample_large/val'
  test_path = '/content/gdrive/MyDrive/Primary Models/sample_large/test'

  # Load all of the data from my google drive
  train_data = torchvision.datasets.ImageFolder(train_path, transform=transform_it)
  val_data = torchvision.datasets.ImageFolder(val_path, transform=transform_it)
  test_data = torchvision.datasets.ImageFolder(test_path, transform=transform_it)

  return train_data, val_data, test_data

# %%
train_data, val_data, test_data = load_data(batch_size=138)
test_loader = torch.utils.data.DataLoader(test_data, batch_size=138, shuffle=True)
print(len(test_loader))
for img, label in test_loader:
  print(img[0].shape)
  break
# Out:
# 1
# torch.Size([3, 224, 224])

# %% [markdown]
# ### **Training**

# %% [markdown]
# ### ResNet18

# %%
resnet18 = torchvision.models.resnet18(pretrained=True)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet18-5c106cde.pth" to /root/.cache/torch/hub/checkpoints/resnet18-5c106cde.pth
# HBox(children=(FloatProgress(value=0.0, max=46827520.0), HTML(value='')))

# %%
resnet18.fc=torch.nn.Linear(in_features=512, out_features=4)

# %%
# For the model checkpoints 
def get_model_name(name, batch_size, learning_rate, epoch):
    """ Generate a name for the model consisting of all the hyperparameter values

    Args:
        config: Configuration object containing the hyperparameters
    Returns:
        path: A string with the hyperparameter name and value concatenated
    """
    path = "model_{0}_bs{1}_lr{2}_epoch{3}".format(name,
                                                   batch_size,
                                                   learning_rate,
                                                   epoch)
    return path

# %%
def get_accuracy(model, data_loader):
    correct = 0
    total = 0
    for imgs, labels in data_loader:
         
        #############################################
        #To Enable GPU Usage
        if use_cuda and torch.cuda.is_available():
          imgs = imgs.cuda()
          labels = labels.cuda()
        #############################################
        
        output = model(imgs)
        
        #select index with maximum prediction score
        pred = output.max(1, keepdim=True)[1]
        correct += pred.eq(labels.view_as(pred)).sum().item()
        total += imgs.shape[0]
    return correct / total

# %%
def train(model, train_data, val_data, batch_size=64, learning_rate=0.001, num_epochs=20):
    torch.manual_seed(1000)
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.Adam(model.parameters(), lr=learning_rate)

    train_loader = torch.utils.data.DataLoader(train_data, batch_size=batch_size, shuffle=True)
    val_loader = torch.utils.data.DataLoader(val_data, batch_size=batch_size, shuffle=True)

    iters, losses, train_acc, val_acc = [], [], [], []

    # training
    n = 0 # the number of iterations
    for epoch in range(num_epochs):
        for imgs, labels in iter(train_loader):
          
          
            #############################################
            #To Enable GPU Usage
            if use_cuda and torch.cuda.is_available():
              #print("GPU is Available")
              imgs = imgs.cuda()
              labels = labels.cuda()
            #############################################
            
              
            out = model(imgs)             # forward pass
            loss = criterion(out, labels) # compute the total loss
            loss.backward()               # backward pass (compute parameter updates)
            optimizer.step()              # make the updates for each parameter
            optimizer.zero_grad()         # a clean up step for PyTorch

            # save the current training information
            iters.append(n)
            losses.append(float(loss)/batch_size)             # compute *average* loss
            train_acc.append(get_accuracy(model, train_loader)) # compute training accuracy 
            val_acc.append(get_accuracy(model, val_loader))  # compute validation accuracy
            n += 1

        # Print the accuracies of validation and training for each epoch to observe how it changes over time 
        print("epoch number: ", epoch+1, "Training accuracy: ",train_acc[epoch], "Validation accuracy: ", val_acc[epoch])
        # Save the current model (checkpoint) to a file
        model_path = get_model_name("resnet50", batch_size, learning_rate, epoch)
        torch.save(model.state_dict(), model_path)      

    # plotting
    plt.title("Training Curve")
    plt.plot(iters, losses, label="Train")
    plt.xlabel("Iterations")
    plt.ylabel("Loss")
    plt.show()

    plt.title("Training Curve")
    plt.plot(iters, train_acc, label="Train")
    plt.plot(iters, val_acc, label="Validation")
    plt.xlabel("Iterations")
    plt.ylabel("Training Accuracy")
    plt.legend(loc='best')
    plt.show()

    print("Final Training Accuracy: {}".format(train_acc[-1]))
    print("Final Validation Accuracy: {}".format(val_acc[-1]))

# %%
import pandas as pd
from sklearn.metrics import *
import seaborn

def get_accuracy_mat(model, data_loader):
    correct = 0
    total = 0
    
    # ADDING STUFF HERE
    predicted_labels = [] # List of predictions made by model
    true_labels = []      # List of labels for images seen by model
    
    for imgs, labels in data_loader:
         
        #############################################
        #To Enable GPU Usage
        # if use_cuda and torch.cuda.is_available():
        #   imgs = imgs.cuda()
        #   labels = labels.cuda()
        #############################################
        
        output = model(imgs)
        
        #select index with maximum prediction score
        pred = output.max(1, keepdim=True)[1]
        correct += pred.eq(labels.view_as(pred)).sum().item()
        total += imgs.shape[0]

        # ADDING STUFF HERE
        predicted_labels.extend(pred.tolist())  # Adds model prediction to list
        true_labels.extend(labels.tolist())     # Adds true label to list

    # Creates the normalized confusion matrix (remove normalize='true' flag for unnormalized) 
    matrix = pd.DataFrame(confusion_matrix(true_labels,predicted_labels,normalize=None),['COVID-19', 'Normal', 'Pneumonial-Bacterial','Pneumonial-Viral'],
                          ['COVID-19', 'Normal', 'Pneumonial-Bacterial','Pneumonial-Viral'])

    # Visual representation of matrix
    seaborn.heatmap(matrix, annot=True, fmt='g', cbar=False, cmap="YlGnBu")
    
    return correct / total

# %% [markdown]
# ### TRAINING RESNET CODE WITH CONFUSION MATRIX

# %%
#Convert to the GPU
use_cuda = True

if use_cuda and torch.cuda.is_available():
  resnet18 = resnet18.to('cuda:0')
  print('CUDA is available!  Training on GPU ...')
else:
  print('CUDA is not available.  Training on CPU ...')
# Batch Size 64
#################################CONSIDER###################################################
train_data, val_data, test_data = load_data(batch_size=64)
train(resnet18, train_data, val_data, batch_size=64, learning_rate=0.001, num_epochs=3)
# Out:
# CUDA is available!  Training on GPU ...
# epoch number:  1 Training accuracy:  0.7070254110612855 Validation accuracy:  0.6993006993006993
# epoch number:  2 Training accuracy:  0.7399103139013453 Validation accuracy:  0.6993006993006993
# epoch number:  3 Training accuracy:  0.7234678624813154 Validation accuracy:  0.7132867132867133
# Final Training Accuracy: 0.9133034379671151
# Final Validation Accuracy: 0.7622377622377622

# %%
resnet18_model = torchvision.models.resnet18(pretrained=True)
resnet18_model.fc=torch.nn.Linear(in_features=512, out_features=4)

# %%
resnet18_path = get_model_name("resnet18", 64, 0.001, 2)
state = torch.load(resnet18_path)
resnet18_model.load_state_dict(state)
# Out:
# <All keys matched successfully>

# %%
test_loader = torch.utils.data.DataLoader(test_data, batch_size=64, shuffle=True)

print(len(test_loader))

# %%
acc = get_accuracy_mat(resnet18_model, test_loader)
print("Test Accuracy of resnet18:", acc)
#print(resnet18_model)
# Out:
# Test Accuracy of resnet18: 0.7753623188405797

# %%
# BATCH SIZE 32
#Convert to the GPU
use_cuda = True

if use_cuda and torch.cuda.is_available():
  resnet18 = resnet18.to('cuda:0')
  print('CUDA is available!  Training on GPU ...')
else:
  print('CUDA is not available.  Training on CPU ...')
# Batch Size 32
train_data, val_data, test_data = load_data(batch_size=32)
train(resnet18, train_data, val_data, batch_size=32, learning_rate=0.001, num_epochs=3)
# Out:
# CUDA is available!  Training on GPU ...
# epoch number:  1 Training accuracy:  0.7817638266068759 Validation accuracy:  0.6573426573426573
# epoch number:  2 Training accuracy:  0.8325859491778774 Validation accuracy:  0.6993006993006993
# epoch number:  3 Training accuracy:  0.8325859491778774 Validation accuracy:  0.7132867132867133
# Final Training Accuracy: 0.8968609865470852
# Final Validation Accuracy: 0.7272727272727273

# %%
resnet18_model2 = torchvision.models.resnet18(pretrained=True)
resnet18_model2.fc=torch.nn.Linear(in_features=512, out_features=4)

resnet18_path2 = get_model_name("resnet18", 32, 0.001, 2)
state = torch.load(resnet18_path2)
resnet18_model2.load_state_dict(state)
# Out:
# <All keys matched successfully>

# %%
test_loader = torch.utils.data.DataLoader(test_data, batch_size=32, shuffle=True)
acc = get_accuracy_mat(resnet18_model2, test_loader)
print("Test Accuracy of resnet18:", acc)
# Out:
# Test Accuracy of resnet18: 0.7463768115942029

# %%
# BATCH SIZE 64 learning rate 0.0001
#Convert to the GPU
use_cuda = True

if use_cuda and torch.cuda.is_available():
  resnet18 = resnet18.to('cuda:0')
  print('CUDA is available!  Training on GPU ...')
else:
  print('CUDA is not available.  Training on CPU ...')
# Batch Size 64 and learning rate = 0.0001
train_data, val_data, test_data = load_data(batch_size=64)
train(resnet18, train_data, val_data, batch_size=64, learning_rate=0.0001, num_epochs=3)
# Out:
# CUDA is available!  Training on GPU ...
# epoch number:  1 Training accuracy:  0.5889387144992526 Validation accuracy:  0.5664335664335665
# epoch number:  2 Training accuracy:  0.750373692077728 Validation accuracy:  0.6783216783216783
# epoch number:  3 Training accuracy:  0.7982062780269058 Validation accuracy:  0.7202797202797203
# Final Training Accuracy: 0.9985052316890882
# Final Validation Accuracy: 0.8601398601398601

# %%
resnet18_model3 = torchvision.models.resnet18(pretrained=True)
resnet18_model3.fc=torch.nn.Linear(in_features=512, out_features=4)

resnet18_path3 = get_model_name("resnet18", 64, 0.0001, 2)
state = torch.load(resnet18_path3)
resnet18_model3.load_state_dict(state)
# Out:
# <All keys matched successfully>

# %%
test_loader = torch.utils.data.DataLoader(test_data, batch_size=64, shuffle=True)
acc = get_accuracy_mat(resnet18_model3, test_loader)
print("Test Accuracy of resnet18:", acc)
# Out:
# Test Accuracy of resnet18: 0.7681159420289855

# %% [markdown]
# ### Resnet50 Confusion Matrix

# %%
resnet50 =torchvision.models.resnet50(pretrained=True)

for param in resnet50.parameters():
  param.requires_grad = False

resnet50.fc=torch.nn.Linear(in_features= 2048, out_features=4)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet50-19c8e357.pth" to /root/.cache/torch/hub/checkpoints/resnet50-19c8e357.pth
# HBox(children=(FloatProgress(value=0.0, max=102502400.0), HTML(value='')))

# %%
#Convert to the GPU
use_cuda = True
if use_cuda and torch.cuda.is_available():
  resnet50 = resnet50.to('cuda:0')
  print('CUDA is available!  Training on GPU ...')
else:
  print('CUDA is not available.  Training on CPU ...')

train_data, val_data, test_data = load_data(batch_size=64)
train(resnet50, train_data, val_data, batch_size=64, learning_rate=0.001, num_epochs=3)
# Out:
# CUDA is available!  Training on GPU ...
# epoch number:  1 Training accuracy:  0.25411061285500747 Validation accuracy:  0.24475524475524477
# epoch number:  2 Training accuracy:  0.2526158445440957 Validation accuracy:  0.2727272727272727
# epoch number:  3 Training accuracy:  0.27802690582959644 Validation accuracy:  0.2867132867132867
# Final Training Accuracy: 0.7877428998505231
# Final Validation Accuracy: 0.7552447552447552

# %%
resnet50_model = torchvision.models.resnet50(pretrained=True)
resnet50_model.fc=torch.nn.Linear(in_features=2048, out_features=4)

resnet50_path = get_model_name("resnet50", 64, 0.001, 2)
state = torch.load(resnet50_path)
resnet50_model.load_state_dict(state)
# Out:
# <All keys matched successfully>

# %%
train_data, val_data, test_data = load_data(batch_size=64)
test_loader = torch.utils.data.DataLoader(test_data, batch_size=64, shuffle=True)
acc = get_accuracy_mat(resnet50_model, test_loader)
print("Test Accuracy of resnet50:", acc)
# Out:
# Test Accuracy of resnet50: 0.7246376811594203

# %%
#Convert to the GPU
use_cuda = True
if use_cuda and torch.cuda.is_available():
  resnet50 = resnet50.to('cuda:0')
  print('CUDA is available!  Training on GPU ...')
else:
  print('CUDA is not available.  Training on CPU ...')

train_data, val_data, test_data = load_data(batch_size=32)
train(resnet50, train_data, val_data, batch_size=32, learning_rate=0.001, num_epochs=3)
# Out:
# CUDA is available!  Training on GPU ...
# epoch number:  1 Training accuracy:  0.2615844544095665 Validation accuracy:  0.26573426573426573
# epoch number:  2 Training accuracy:  0.24813153961136025 Validation accuracy:  0.2517482517482518
# epoch number:  3 Training accuracy:  0.2436472346786248 Validation accuracy:  0.23776223776223776
# Final Training Accuracy: 0.7533632286995515
# Final Validation Accuracy: 0.7482517482517482

# %%
resnet50_model = torchvision.models.resnet50(pretrained=True)
resnet50_model.fc=torch.nn.Linear(in_features=2048, out_features=4)

resnet50_path = get_model_name("resnet50", 32, 0.001, 2)
state = torch.load(resnet50_path)
resnet50_model.load_state_dict(state)
# Out:
# <All keys matched successfully>

# %%
train_data, val_data, test_data = load_data(batch_size=32)
test_loader = torch.utils.data.DataLoader(test_data, batch_size=32, shuffle=True)
acc = get_accuracy_mat(resnet50_model, test_loader)
print("Test Accuracy of resnet50:", acc)
# Out:
# Test Accuracy of resnet50: 0.7101449275362319

# %%
#Convert to the GPU
use_cuda = True
if use_cuda and torch.cuda.is_available():
  resnet50 = resnet50.to('cuda:0')
  print('CUDA is available!  Training on GPU ...')
else:
  print('CUDA is not available.  Training on CPU ...')

train_data, val_data, test_data = load_data(batch_size=64)
train(resnet50, train_data, val_data, batch_size=64, learning_rate=0.0001, num_epochs=1)
# Out:
# CUDA is available!  Training on GPU ...
# epoch number:  1 Training accuracy:  0.7937219730941704 Validation accuracy:  0.7622377622377622
# Final Training Accuracy: 0.796711509715994
# Final Validation Accuracy: 0.7412587412587412

# %%
resnet50_model = torchvision.models.resnet50(pretrained=True)
resnet50_model.fc=torch.nn.Linear(in_features=2048, out_features=4)

resnet50_path = get_model_name("resnet50", 64, 0.0001, 0)
state = torch.load(resnet50_path)
resnet50_model.load_state_dict(state)
# Out:
# <All keys matched successfully>

# %%
train_data, val_data, test_data = load_data(batch_size=64)
test_loader = torch.utils.data.DataLoader(test_data, batch_size=64, shuffle=True)
acc = get_accuracy_mat(resnet50_model, test_loader)
print("Test Accuracy of resnet50:", acc)
# Out:
# Test Accuracy of resnet50: 0.7246376811594203

# %%
resnet50_model = torchvision.models.resnet50(pretrained=True)
resnet50_model.fc=torch.nn.Linear(in_features=2048, out_features=4)

resnet50_path = get_model_name("resnet50", 64, 0.0001, 2)
state = torch.load(resnet50_path)
resnet50_model.load_state_dict(state)
# Out:
# <All keys matched successfully>

# %%
train_data, val_data, test_data = load_data(batch_size=64)
test_loader = torch.utils.data.DataLoader(test_data, batch_size=64, shuffle=True)
acc = get_accuracy_mat(resnet50_model, test_loader)
print("Test Accuracy of resnet50:", acc)
# Out:
# Test Accuracy of resnet50: 0.7246376811594203

# %% [markdown]
# ### ResNet101

# %%
resnet101=torchvision.models.resnet101(pretrained=True)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet101-5d3b4d8f.pth" to /root/.cache/torch/hub/checkpoints/resnet101-5d3b4d8f.pth
# HBox(children=(FloatProgress(value=0.0, max=178728960.0), HTML(value='')))

# %%
# Freeze weights
for param in resnet101.parameters():
  param.requires_grad = False
resnet101.fc=torch.nn.Linear(in_features= 2048, out_features=4)

# %%
#Convert to the GPU
use_cuda = True

if use_cuda and torch.cuda.is_available():
  resnet101 = resnet101.to('cuda:0')
  print('CUDA is available!  Training on GPU ...')
else:
  print('CUDA is not available.  Training on CPU ...')
# Batch Size 64
train_data, val_data, test_data = load_data(batch_size=128)
train(resnet101, train_data, val_data, batch_size=128, learning_rate=0.0001, num_epochs=1)
# Out:
# CUDA is available!  Training on GPU ...
# epoch number:  1 Training accuracy:  0.5022421524663677 Validation accuracy:  0.46153846153846156
# Final Training Accuracy: 0.5949177877428998
# Final Validation Accuracy: 0.5734265734265734

# %%
resnet101_model = torchvision.models.resnet101(pretrained=True)
resnet101_model.fc=torch.nn.Linear(in_features=2048, out_features=4)

resnet101_path = get_model_name("resnet101", 128, 0.0001, 0)
state = torch.load(resnet101_path)
resnet101_model.load_state_dict(state)
# Out:
# <All keys matched successfully>

# %%
train_data, val_data, test_data = load_data(batch_size=128)
test_loader = torch.utils.data.DataLoader(test_data, batch_size=128, shuffle=True)
acc = get_accuracy_mat(resnet101_model, test_loader)
print("Test Accuracy of resnet101:", acc)
# Out:
# Test Accuracy of resnet101: 0.5434782608695652

# %% [markdown]
# ### Tests with Added Layer (ResNet18)

# %%
resnet18 =torchvision.models.resnet18(pretrained=True)
n_inputs = resnet18.fc.in_features

# %%
resnet18.fc = nn.Sequential(
                      nn.Linear(n_inputs, 256),
                      nn.ReLU(),
                      nn.Dropout(0.4),
                      nn.Linear(256, 4))

# %%
#Convert to the GPU
use_cuda = True

if use_cuda and torch.cuda.is_available():
  resnet18 = resnet18.to('cuda:0')
  print('CUDA is available!  Training on GPU ...')
else:
  print('CUDA is not available.  Training on CPU ...')
# Batch Size 64

train_data, val_data, test_data = load_data(batch_size=64)
train(resnet18, train_data, val_data, batch_size=64, learning_rate=0.001, num_epochs=10)
# Out:
# CUDA is available!  Training on GPU ...
# epoch number:  1 Training accuracy:  0.4484304932735426 Validation accuracy:  0.36363636363636365
# epoch number:  2 Training accuracy:  0.7952167414050823 Validation accuracy:  0.7412587412587412
# epoch number:  3 Training accuracy:  0.7638266068759342 Validation accuracy:  0.6993006993006993
# epoch number:  4 Training accuracy:  0.7458893871449925 Validation accuracy:  0.6993006993006993
# epoch number:  5 Training accuracy:  0.7892376681614349 Validation accuracy:  0.7762237762237763
# epoch number:  6 Training accuracy:  0.8191330343796711 Validation accuracy:  0.7622377622377622
# epoch number:  7 Training accuracy:  0.7488789237668162 Validation accuracy:  0.7062937062937062
# epoch number:  8 Training accuracy:  0.7399103139013453 Validation accuracy:  0.7622377622377622
# epoch number:  9 Training accuracy:  0.7653213751868461 Validation accuracy:  0.7622377622377622
# epoch number:  10 Training accuracy:  0.8310911808669657 Validation accuracy:  0.7692307692307693
# Final Training Accuracy: 0.9850523168908819
# Final Validation Accuracy: 0.7622377622377622

# %%
resnet18.fc=torch.nn.Linear(in_features=n_inputs, out_features=4)

# %%
#Convert to the GPU
use_cuda = True

if use_cuda and torch.cuda.is_available():
  resnet18 = resnet18.to('cuda:0')
  print('CUDA is available!  Training on GPU ...')
else:
  print('CUDA is not available.  Training on CPU ...')
# Batch Size 64

train_data, val_data, test_data = load_data(batch_size=64)
train(resnet18, train_data, val_data, batch_size=64, learning_rate=0.001, num_epochs=10)
# Out:
# CUDA is available!  Training on GPU ...
# epoch number:  1 Training accuracy:  0.7892376681614349 Validation accuracy:  0.7342657342657343
# epoch number:  2 Training accuracy:  0.7608370702541106 Validation accuracy:  0.7622377622377622
# epoch number:  3 Training accuracy:  0.7518684603886397 Validation accuracy:  0.7132867132867133
# epoch number:  4 Training accuracy:  0.7772795216741405 Validation accuracy:  0.7482517482517482
# epoch number:  5 Training accuracy:  0.8011958146487295 Validation accuracy:  0.7482517482517482
# epoch number:  6 Training accuracy:  0.8236173393124065 Validation accuracy:  0.7412587412587412
# epoch number:  7 Training accuracy:  0.7653213751868461 Validation accuracy:  0.7272727272727273
# epoch number:  8 Training accuracy:  0.7997010463378177 Validation accuracy:  0.7272727272727273
# epoch number:  9 Training accuracy:  0.8011958146487295 Validation accuracy:  0.7622377622377622
# epoch number:  10 Training accuracy:  0.8146487294469357 Validation accuracy:  0.7202797202797203
# Final Training Accuracy: 0.9880418535127056
# Final Validation Accuracy: 0.8181818181818182

# %%
resnet18.fc = nn.Sequential(
                      nn.Linear(n_inputs , 256),
                      nn.BatchNorm1d(256),
                      nn.Dropout(0.2),
                      nn.Linear(256 , 128),
                      nn.Linear(128 , 4))

# %%
#Convert to the GPU
use_cuda = True

if use_cuda and torch.cuda.is_available():
  resnet18 = resnet18.to('cuda:0')
  print('CUDA is available!  Training on GPU ...')
else:
  print('CUDA is not available.  Training on CPU ...')
# Batch Size 64

train_data, val_data, test_data = load_data(batch_size=64)
train(resnet18, train_data, val_data, batch_size=64, learning_rate=0.001, num_epochs=10)
# Out:
# CUDA is available!  Training on GPU ...
# epoch number:  1 Training accuracy:  0.8221225710014948 Validation accuracy:  0.6783216783216783
# epoch number:  2 Training accuracy:  0.9506726457399103 Validation accuracy:  0.7832167832167832
# epoch number:  3 Training accuracy:  0.9671150971599403 Validation accuracy:  0.8041958041958042
# epoch number:  4 Training accuracy:  0.9431988041853513 Validation accuracy:  0.7972027972027972
# epoch number:  5 Training accuracy:  0.9701046337817638 Validation accuracy:  0.7972027972027972
# epoch number:  6 Training accuracy:  0.9790732436472347 Validation accuracy:  0.8181818181818182
# epoch number:  7 Training accuracy:  0.9611360239162929 Validation accuracy:  0.7902097902097902
# epoch number:  8 Training accuracy:  0.9431988041853513 Validation accuracy:  0.7832167832167832
# epoch number:  9 Training accuracy:  0.9641255605381166 Validation accuracy:  0.7902097902097902
# epoch number:  10 Training accuracy:  0.9805680119581465 Validation accuracy:  0.7692307692307693
# Final Training Accuracy: 0.9880418535127056
# Final Validation Accuracy: 0.7482517482517482

# %%
#Convert to the GPU
use_cuda = True

if use_cuda and torch.cuda.is_available():
  resnet18 = resnet18.to('cuda:0')
  print('CUDA is available!  Training on GPU ...')
else:
  print('CUDA is not available.  Training on CPU ...')
# Batch Size 64

train_data, val_data, test_data = load_data(batch_size=32)
train(resnet18, train_data, val_data, batch_size=32, learning_rate=0.001, num_epochs=5)
# Out:
# CUDA is available!  Training on GPU ...
# epoch number:  1 Training accuracy:  0.9192825112107623 Validation accuracy:  0.6783216783216783
# epoch number:  2 Training accuracy:  0.9192825112107623 Validation accuracy:  0.6853146853146853
# epoch number:  3 Training accuracy:  0.8759342301943199 Validation accuracy:  0.6363636363636364
# epoch number:  4 Training accuracy:  0.9252615844544095 Validation accuracy:  0.6363636363636364
# epoch number:  5 Training accuracy:  0.9521674140508222 Validation accuracy:  0.6923076923076923
# Final Training Accuracy: 0.9790732436472347
# Final Validation Accuracy: 0.8041958041958042

# %%
#Convert to the GPU
use_cuda = True

if use_cuda and torch.cuda.is_available():
  resnet18 = resnet18.to('cuda:0')
  print('CUDA is available!  Training on GPU ...')
else:
  print('CUDA is not available.  Training on CPU ...')
# Batch Size 64

train_data, val_data, test_data = load_data(batch_size=64)
train(resnet18, train_data, val_data, batch_size=64, learning_rate=0.001, num_epochs=1)
# Out:
# CUDA is available!  Training on GPU ...
# epoch number:  1 Training accuracy:  0.9790732436472347 Validation accuracy:  0.7972027972027972
# Final Training Accuracy: 0.9955156950672646
# Final Validation Accuracy: 0.8111888111888111

# %%
resnet18.fc = nn.Sequential(
                      nn.Linear(n_inputs , 256),
                      nn.BatchNorm1d(256),
                      nn.Dropout(0.2),
                      nn.Linear(256 , 128),
                      nn.Linear(128 , 4))

# %%
#Convert to the GPU
use_cuda = True

if use_cuda and torch.cuda.is_available():
  resnet18 = resnet18.to('cuda:0')
  print('CUDA is available!  Training on GPU ...')
else:
  print('CUDA is not available.  Training on CPU ...')
# Batch Size 64

train_data, val_data, test_data = load_data(batch_size=64)
train(resnet18, train_data, val_data, batch_size=64, learning_rate=0.001, num_epochs=3)
# Out:
# CUDA is available!  Training on GPU ...
# epoch number:  1 Training accuracy:  0.7414050822122571 Validation accuracy:  0.7062937062937062
# epoch number:  2 Training accuracy:  0.7458893871449925 Validation accuracy:  0.7272727272727273
# epoch number:  3 Training accuracy:  0.7623318385650224 Validation accuracy:  0.7482517482517482
# Final Training Accuracy: 0.9312406576980568
# Final Validation Accuracy: 0.8461538461538461

# %% [markdown]
# ### Tests with Added Layer (ResNet50)

# %%
resnet50 =torchvision.models.resnet50(pretrained=True)
n_inputs = resnet50.fc.in_features

for param in resnet50.parameters():
  param.requires_grad = False

# %%
resnet50.fc = nn.Sequential(
                      nn.Linear(n_inputs , 1024),
                      nn.BatchNorm1d(1024),
                      nn.Dropout(0.2),
                      nn.Linear(1024 , 512),
                      nn.Linear(512 , 4))

# %%
#Convert to the GPU
use_cuda = True
if use_cuda and torch.cuda.is_available():
  resnet50 = resnet50.to('cuda:0')
  print('CUDA is available!  Training on GPU ...')
else:
  print('CUDA is not available.  Training on CPU ...')

train_data, val_data, test_data = load_data(batch_size=32)
train(resnet50, train_data, val_data, batch_size=32, learning_rate=0.001, num_epochs=2)
# Out:
# CUDA is available!  Training on GPU ...
# epoch number:  1 Training accuracy:  0.71898355754858 Validation accuracy:  0.6783216783216783
# epoch number:  2 Training accuracy:  0.7428998505231689 Validation accuracy:  0.7412587412587412
# Final Training Accuracy: 0.8714499252615845
# Final Validation Accuracy: 0.7832167832167832

# %%
resnet50_model = torchvision.models.resnet50(pretrained=True)
n_inputs = resnet50_model.fc.in_features

for param in resnet50_model.parameters():
  param.requires_grad = False

resnet50_model.fc = nn.Sequential(
                      nn.Linear(n_inputs , 1024),
                      nn.BatchNorm1d(1024),
                      nn.Dropout(0.2),
                      nn.Linear(1024 , 512),
                      nn.Linear(512 , 4))


resnet50_path = get_model_name("resnet50", 32, 0.001, 1)
state = torch.load(resnet50_path)
resnet50_model.load_state_dict(state)
# Out:
# <All keys matched successfully>

# %%
train_data, val_data, test_data = load_data(batch_size=32)
test_loader = torch.utils.data.DataLoader(test_data, batch_size=32, shuffle=True)
acc = get_accuracy_mat(resnet50_model, test_loader)
print("Test Accuracy of resnet50:", acc)
# Out:
# Test Accuracy of resnet50: 0.7318840579710145

# %%
#Convert to the GPU
use_cuda = True
if use_cuda and torch.cuda.is_available():
  resnet50 = resnet50.to('cuda:0')
  print('CUDA is available!  Training on GPU ...')
else:
  print('CUDA is not available.  Training on CPU ...')

train_data, val_data, test_data = load_data(batch_size=64)
train(resnet50, train_data, val_data, batch_size=64, learning_rate=0.0001, num_epochs=2)
# Out:
# CUDA is available!  Training on GPU ...
# epoch number:  1 Training accuracy:  0.6113602391629297 Validation accuracy:  0.5524475524475524
# epoch number:  2 Training accuracy:  0.7279521674140508 Validation accuracy:  0.6923076923076923
# Final Training Accuracy: 0.852017937219731
# Final Validation Accuracy: 0.7692307692307693

# %%
resnet50_model = torchvision.models.resnet50(pretrained=True)
n_inputs = resnet50_model.fc.in_features

for param in resnet50_model.parameters():
  param.requires_grad = False

resnet50_model.fc = nn.Sequential(
                      nn.Linear(n_inputs , 1024),
                      nn.BatchNorm1d(1024),
                      nn.Dropout(0.2),
                      nn.Linear(1024 , 512),
                      nn.Linear(512 , 4))


resnet50_path = get_model_name("resnet50", 64, 0.0001, 1)
state = torch.load(resnet50_path)
resnet50_model.load_state_dict(state)
# Out:
# <All keys matched successfully>

# %%
train_data, val_data, test_data = load_data(batch_size=64)
test_loader = torch.utils.data.DataLoader(test_data, batch_size=64, shuffle=True)
acc = get_accuracy_mat(resnet50_model, test_loader)
print("Test Accuracy of resnet50:", acc)
# Out:
# Test Accuracy of resnet50: 0.7028985507246377
